# %% [markdown]
# ## Plot top features according to the data calculated in all-preprocessing.ipynb

# %%
import matplotlib.pyplot as plt

top_features_1 = [('to', 65835.23283663149), ('the', 61665.139418985695), ('you', 45687.330463064354), ('my', 45244.51934191271), ('and', 41132.20383064825), ('is', 39170.44972388171), ('it', 36867.08903840576), ('for', 34904.324530249316), ('in', 33514.38489202365), ('im', 31651.344611942233), ('of', 29303.03594661117), ('me', 29074.21523839432), ('on', 28311.5647049693), ('so', 27286.186178349824), ('have', 26385.71595626988),
                  ('that', 26063.432099570862), ('just', 23543.091825624237), ('with', 22516.027822836364), ('but', 22093.83883740727), ('at', 21821.121387885076), ('its', 21803.13351589101), ('not', 21440.4468605445), ('be', 21235.720515902012), ('good', 20838.09033067403), ('was', 20321.02675523133), ('this', 18914.003792425356), ('now', 18817.127652755713), ('day', 18285.165299068867), ('up', 18020.19404179564), ('no', 16965.46528807754)]

top_features_2 = [('username', 96450.79269098859), ('to', 65555.53092948113), ('the', 61347.48541152642), ('you', 45450.20664093043), ('my', 44972.58085772204), ('and', 40916.40080584383), ('is', 38921.171077499406), ('it', 36664.70853603441), ('for', 34672.015709526386), ('in', 33381.03242110935), ('im', 31473.232247563064), ('of', 29171.727966559407), ('me', 28888.214378754932), ('on', 28180.21655455562), ('so', 27156.971670026796),
                  ('have', 26267.184160687466), ('that', 25947.574650401573), ('just', 23415.920487585066), ('with', 22384.93050183552), ('but', 22006.536502085648), ('at', 21694.494285631656), ('its', 21668.03916423081), ('not', 21330.842914392917), ('be', 21156.89909159589), ('good', 21073.251490485552), ('was', 20225.770230511534), ('url', 19694.730864708887), ('this', 18760.068130006908), ('now', 18715.913087738543), ('day', 18208.231782000283)]

top_features_3 = [('username', 120749.74626687301), ('im', 37102.01259432468), ('just', 27573.41209234373), ('good', 24612.678209500194), ('url', 22893.640490907113), ('day', 21689.12555214832), ('like', 19562.910472677893), ('love', 18686.732610313553), ('work', 18505.934128534784), ('dont', 18244.167904894606), ('going', 17956.680204928227), ('today', 17745.75437442471), ('got', 16065.359719079583), ('lol', 15804.381739731538), ('time', 15567.498402468795),
                  ('know', 15396.66118760435), ('thanks', 15347.888670719927), ('really', 14203.53618752435), ('want', 13472.17528620247), ('miss', 13119.024954015975), ('night', 12369.76764635972), ('home', 12197.016717898863), ('think', 12139.213419440124), ('oh', 11916.015293047227), ('new', 11842.805753815874), ('morning', 11063.235519371136), ('need', 10894.895188672184), ('twitter', 10470.64549090828), ('great', 10445.375779825283), ('hope', 10326.888511900797)]

top_features_4 = [('username', 97400.71507008366), ('to', 65978.52766673474), ('the', 61736.72766753322), ('is', 57621.19081823049), ('you', 49566.62686914161), ('it', 48822.6829056735), ('my', 45226.74382041249), ('not', 41873.48395239971), ('and', 41165.37851486808), ('am', 37871.09358501741), ('for', 34878.78053407831), ('in', 33607.748066267566), ('have', 31194.994398948445), ('that', 30874.814033463634), ('of', 29370.340325908477),
                  ('me', 29100.197966547697), ('on', 28362.25286875883), ('will', 27874.639250445904), ('so', 27410.37250737603), ('do', 25620.24864368791), ('are', 25542.220715798918), ('just', 23552.2263331958), ('we', 22835.427552529032), ('with', 22506.723246834383), ('but', 22193.239182135807), ('at', 21831.594900126347), ('be', 21417.379888133895), ('was', 21370.91721307466), ('good', 21245.763617180604), ('url', 19804.702394570064)]

top_features_5 = [('username', 125070.3965471675), ('just', 28081.77871193382), ('good', 25146.906031383845), ('url', 23155.474649477623), ('day', 21955.930355411983), ('like', 20077.426869357558), ('love', 19019.795429449478), ('work', 18859.686066412123), ('going', 18402.147540434427), ('today', 18019.58975114245), ('got', 16368.845414486248), ('lol', 16185.644469277997), ('know', 16034.914155178869), ('time', 15821.048586796725), ('thanks', 15522.194927357634),
                  ('did', 15250.263918246112), ('really', 14521.875135188035), ('want', 13799.351945815395), ('miss', 13344.110868347), ('think', 12553.13786718378), ('night', 12520.598881425592), ('home', 12400.310893606069), ('oh', 12183.20593825284), ('new', 11983.40313373367), ('morning', 11191.647281829908), ('need', 11056.89378123089), ('twitter', 10667.20516212461), ('great', 10629.20690062899), ('hope', 10565.599776442667), ('tomorrow', 10330.615309094248)]

top_features_array = [top_features_1[0:20], top_features_2[0:20],
                      top_features_3[0:20], top_features_4[0:20], top_features_5[0:20]]

for l in top_features_array:
    ind = []
    fre = []
    for item in l:
        ind.append(item[0])
        fre.append(item[1])
    
    A=6
    plt.rc('figure', figsize=[46.82 * .5**(.5 * A), 33.11 * .5**(.5 * A)], dpi=141)
    plt.barh(ind, fre,
                color='#86bf91')
    plt.xlabel("frequency over all documents")
    plt.ylabel("features")
    plt.title("Top 20 features of preprocessing series %d" % (top_features_array.index(l) + 1))
    plt.yticks(rotation = 0)
    plt.gca().invert_yaxis()
    plt.show()
