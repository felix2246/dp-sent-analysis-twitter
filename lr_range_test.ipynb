# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import gc

import warnings
warnings.filterwarnings('ignore')

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 100
LEARNING_RATE = 1e-2
N = 1579634
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
step = 3
initial_lr = 1e-7

#increase lr by factor 10 every <steps> epochs
def exp_scheduler(epoch, lr):
    return initial_lr * pow(base=10, exp=epoch / step)

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_loss_learningrate(history):
    lr_epochs = [exp_scheduler(e, initial_lr)
                 for e in range(0, len(history.history['loss']))]

    # summarize history for loss
    plt.plot(history.history['lr'],
             history.history['loss'], label="train")
    plt.plot(history.history['lr'],
             history.history['val_loss'], label="test")
    plt.title('model loss per learning rate')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('learning rate')
    plt.xscale('log')
    plt.show()

# %%
def plot_acc_learningrate(history):
    lr_epochs = [exp_scheduler(e, initial_lr)
                 for e in range(0, len(history.history['accuracy']))]

    # summarize history for loss
    plt.plot(history.history['lr'],
             history.history['accuracy'], label="train")
    plt.plot(history.history['lr'],
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy per learning rate')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('learning rate')
    plt.xscale('log')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)

    #callback
    schedule_lr = tf.keras.callbacks.LearningRateScheduler(
        exp_scheduler, verbose=1)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(N / BATCH_SIZE), epochs=21,
                        use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[schedule_lr])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    save_history_to_file(
        history, "models/histories/history_%s_row_%d.csv" % (metric, preprocessing_row))
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)
    plot_loss_learningrate(history)
    plot_acc_learningrate(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/m_%s_row_%d.hdf5" %
                            (metric, preprocessing_row))
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)

    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)
    
    #train LR
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val, metric= metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
sentiment_analysis(remove_stop_words=False, metric = "count", preprocessing_row = 2)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: count                                           ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
#
# Epoch 1: LearningRateScheduler setting learning rate to 1e-07.
# Epoch 1/21
# 98728/98728 [==============================] - 108s 1ms/step - loss: 0.6937 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5120 - lr: 1.0000e-07
#
# Epoch 2: LearningRateScheduler setting learning rate to 2.1544346900318838e-07.
# Epoch 2/21
# 98728/98728 [==============================] - 102s 1ms/step - loss: 0.6922 - accuracy: 0.5234 - val_loss: 0.6910 - val_accuracy: 0.5370 - lr: 2.1544e-07
#
# Epoch 3: LearningRateScheduler setting learning rate to 4.6415888336127784e-07.
# Epoch 3/21
# 98728/98728 [==============================] - 96s 973us/step - loss: 0.6890 - accuracy: 0.5576 - val_loss: 0.6869 - val_accuracy: 0.5766 - lr: 4.6416e-07
#
# Epoch 4: LearningRateScheduler setting learning rate to 1e-06.
# Epoch 4/21
# 98728/98728 [==============================] - 96s 969us/step - loss: 0.6831 - accuracy: 0.5971 - val_loss: 0.6794 - val_accuracy: 0.6117 - lr: 1.0000e-06
#
# Epoch 5: LearningRateScheduler setting learning rate to 2.154434690031883e-06.
# Epoch 5/21
# 98728/98728 [==============================] - 95s 965us/step - loss: 0.6730 - accuracy: 0.6228 - val_loss: 0.6673 - val_accuracy: 0.6288 - lr: 2.1544e-06
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.641588833612779e-06.
# Epoch 6/21
# 98728/98728 [==============================] - 100s 1ms/step - loss: 0.6581 - accuracy: 0.6350 - val_loss: 0.6509 - val_accuracy: 0.6393 - lr: 4.6416e-06
#
# Epoch 7: LearningRateScheduler setting learning rate to 9.999999999999999e-06.
# Epoch 7/21
# 98728/98728 [==============================] - 99s 1ms/step - loss: 0.6393 - accuracy: 0.6503 - val_loss: 0.6304 - val_accuracy: 0.6597 - lr: 1.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 2.1544346900318844e-05.
# Epoch 8/21
# 98728/98728 [==============================] - 99s 1ms/step - loss: 0.6160 - accuracy: 0.6762 - val_loss: 0.6049 - val_accuracy: 0.6894 - lr: 2.1544e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.641588833612777e-05.
# Epoch 9/21
# 98728/98728 [==============================] - 98s 988us/step - loss: 0.5876 - accuracy: 0.7073 - val_loss: 0.5760 - val_accuracy: 0.7186 - lr: 4.6416e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 9.999999999999999e-05.
# Epoch 10/21
# 98728/98728 [==============================] - 98s 988us/step - loss: 0.5583 - accuracy: 0.7328 - val_loss: 0.5477 - val_accuracy: 0.7414 - lr: 1.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.00021544346900318845.
# Epoch 11/21
# 98728/98728 [==============================] - 98s 988us/step - loss: 0.5320 - accuracy: 0.7516 - val_loss: 0.5233 - val_accuracy: 0.7572 - lr: 2.1544e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.00046415888336127773.
# Epoch 12/21
# 98728/98728 [==============================] - 99s 999us/step - loss: 0.5098 - accuracy: 0.7659 - val_loss: 0.5039 - val_accuracy: 0.7690 - lr: 4.6416e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.001.
# Epoch 13/21
# 98728/98728 [==============================] - 100s 1ms/step - loss: 0.4934 - accuracy: 0.7759 - val_loss: 0.4895 - val_accuracy: 0.7781 - lr: 0.0010
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.002154434690031882.
# Epoch 14/21
# 98728/98728 [==============================] - 99s 1ms/step - loss: 0.4806 - accuracy: 0.7828 - val_loss: 0.4792 - val_accuracy: 0.7853 - lr: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0046415888336127815.
# Epoch 15/21
# 98728/98728 [==============================] - 98s 989us/step - loss: 0.4734 - accuracy: 0.7867 - val_loss: 0.4729 - val_accuracy: 0.7864 - lr: 0.0046
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.01.
# Epoch 16/21
# 98728/98728 [==============================] - 98s 993us/step - loss: 0.4704 - accuracy: 0.7880 - val_loss: 0.4725 - val_accuracy: 0.7845 - lr: 0.0100
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.021544346900318822.
# Epoch 17/21
# 98728/98728 [==============================] - 98s 997us/step - loss: 0.4739 - accuracy: 0.7858 - val_loss: 0.4798 - val_accuracy: 0.7793 - lr: 0.0215
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.04641588833612782.
# Epoch 18/21
# 98728/98728 [==============================] - 97s 984us/step - loss: 0.4884 - accuracy: 0.7782 - val_loss: 0.4866 - val_accuracy: 0.7776 - lr: 0.0464
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.09999999999999999.
# Epoch 19/21
# 98728/98728 [==============================] - 97s 986us/step - loss: 0.5272 - accuracy: 0.7633 - val_loss: 0.5213 - val_accuracy: 0.7645 - lr: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.21544346900318823.
# Epoch 20/21
# 98728/98728 [==============================] - 98s 988us/step - loss: 0.6487 - accuracy: 0.7396 - val_loss: 0.6088 - val_accuracy: 0.7529 - lr: 0.2154
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.4641588833612782.
# Epoch 21/21
# 98728/98728 [==============================] - 102s 1ms/step - loss: 1.0571 - accuracy: 0.7177 - val_loss: 1.2441 - val_accuracy: 0.6910 - lr: 0.4642
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80       177
#            1       0.79      0.86      0.82       182
#
#     accuracy                           0.81       359
#    macro avg       0.81      0.81      0.81       359
# weighted avg       0.81      0.81      0.81       359
#
# Accuracy: 0.8105849582172702
