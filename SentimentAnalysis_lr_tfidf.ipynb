# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
from sklearn.metrics import classification_report, accuracy_score, plot_confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
import keras
import tensorflow_privacy.privacy.optimizers as optimizers
import gc
from tensorflow.keras import backend as k

import warnings
warnings.filterwarnings('ignore')
#tf.compat.v1.disable_v2_behavior()

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 200
LEARNING_RATE = 1e-2
N = 1579634
N_TRAINING = 1421664
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def build_lr_model_DP():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(1, activation='sigmoid',
                    input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=optimizers.dp_optimizer_keras.DPKerasSGDOptimizer(
            l2_norm_clip=1,
            noise_multiplier=0.795,
            num_microbatches=BATCH_SIZE,
            learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)
    
    #callbacks
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                                     patience=3, min_lr=1e-6, verbose=1, min_delta=1e-5)

    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="models/m_%s_row_%d.hdf5" % (metric, preprocessing_row),
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')

    es = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                          patience=7,
                                          verbose=1,
                                          mode="min",
                                          min_delta=1e-5)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(len(y_train) / BATCH_SIZE), epochs=MAX_EPOCHS,
                                  use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[reduce_lr, checkpoint, es])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    save_history_to_file(
        history, "models/histories/history_%s_row_%d.csv" % (metric, preprocessing_row))
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/m_%s_row_%d.hdf5" %
                                            (metric, preprocessing_row))
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)
        
    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)

    #leave out 6 samples because length has to be divisible by BATCH_SIZE (limitation by tensorflow privacy)
    leave_out_samples_X = X_train[-6:]
    leave_out_samples_y = y_train[-6:]
    X_train = X_train[:-6]
    y_train = y_train[:-6]
    
    #train LR Model
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test,
                      X_val=X_val, y_val=y_val, metric=metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
for i in range(1, 6):  # [1,2,3,4,5]
    # Rows 3 and 5 expect removal of stopwords
    remove_stop_words = True if i in [3, 5] else False
    sentiment_analysis(remove_stop_words, metric= "tfidf", preprocessing_row=i)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: tfidf                                           ║
# ║                              Preprocessing row: 1                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_1.csv
# Load test data from data/csv_rows/test_row_1.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5170 - accuracy: 0.7604
# Epoch 1: val_loss improved from inf to 0.48444, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 88s 992us/step - loss: 0.5170 - accuracy: 0.7604 - val_loss: 0.4844 - val_accuracy: 0.7745 - lr: 0.0100
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.7811
# Epoch 2: val_loss improved from 0.48444 to 0.47062, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 89s 1ms/step - loss: 0.4740 - accuracy: 0.7811 - val_loss: 0.4706 - val_accuracy: 0.7828 - lr: 0.0100
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7855
# Epoch 3: val_loss improved from 0.47062 to 0.46602, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 91s 1ms/step - loss: 0.4649 - accuracy: 0.7855 - val_loss: 0.4660 - val_accuracy: 0.7825 - lr: 0.0100
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.7877
# Epoch 4: val_loss improved from 0.46602 to 0.46189, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 87s 983us/step - loss: 0.4605 - accuracy: 0.7877 - val_loss: 0.4619 - val_accuracy: 0.7868 - lr: 0.0100
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.7889
# Epoch 5: val_loss improved from 0.46189 to 0.46018, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.4578 - accuracy: 0.7889 - val_loss: 0.4602 - val_accuracy: 0.7868 - lr: 0.0100
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.7896
# Epoch 6: val_loss improved from 0.46018 to 0.45898, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 91s 1ms/step - loss: 0.4561 - accuracy: 0.7896 - val_loss: 0.4590 - val_accuracy: 0.7887 - lr: 0.0100
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4549 - accuracy: 0.7903
# Epoch 7: val_loss improved from 0.45898 to 0.45793, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4549 - accuracy: 0.7903 - val_loss: 0.4579 - val_accuracy: 0.7894 - lr: 0.0100
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4540 - accuracy: 0.7905
# Epoch 8: val_loss improved from 0.45793 to 0.45724, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4540 - accuracy: 0.7905 - val_loss: 0.4572 - val_accuracy: 0.7886 - lr: 0.0100
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4534 - accuracy: 0.7907
# Epoch 9: val_loss improved from 0.45724 to 0.45691, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4534 - accuracy: 0.7907 - val_loss: 0.4569 - val_accuracy: 0.7880 - lr: 0.0100
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4529 - accuracy: 0.7909
# Epoch 10: val_loss improved from 0.45691 to 0.45636, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4529 - accuracy: 0.7909 - val_loss: 0.4564 - val_accuracy: 0.7886 - lr: 0.0100
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.7911
# Epoch 11: val_loss did not improve from 0.45636
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4524 - accuracy: 0.7911 - val_loss: 0.4564 - val_accuracy: 0.7880 - lr: 0.0100
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4521 - accuracy: 0.7911
# Epoch 12: val_loss did not improve from 0.45636
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4521 - accuracy: 0.7911 - val_loss: 0.4568 - val_accuracy: 0.7905 - lr: 0.0100
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.7915
# Epoch 13: val_loss improved from 0.45636 to 0.45576, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4519 - accuracy: 0.7915 - val_loss: 0.4558 - val_accuracy: 0.7901 - lr: 0.0100
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.7914
# Epoch 14: val_loss did not improve from 0.45576
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4517 - accuracy: 0.7914 - val_loss: 0.4563 - val_accuracy: 0.7905 - lr: 0.0100
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.7914
# Epoch 15: val_loss improved from 0.45576 to 0.45566, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4515 - accuracy: 0.7914 - val_loss: 0.4557 - val_accuracy: 0.7886 - lr: 0.0100
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.7914
# Epoch 16: val_loss improved from 0.45566 to 0.45550, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4514 - accuracy: 0.7914 - val_loss: 0.4555 - val_accuracy: 0.7889 - lr: 0.0100
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.7914
# Epoch 17: val_loss improved from 0.45550 to 0.45528, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4513 - accuracy: 0.7914 - val_loss: 0.4553 - val_accuracy: 0.7892 - lr: 0.0100
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.7916
# Epoch 18: val_loss did not improve from 0.45528
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4512 - accuracy: 0.7916 - val_loss: 0.4554 - val_accuracy: 0.7902 - lr: 0.0100
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.7916
# Epoch 19: val_loss did not improve from 0.45528
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4511 - accuracy: 0.7916 - val_loss: 0.4560 - val_accuracy: 0.7874 - lr: 0.0100
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.7917
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 20: val_loss did not improve from 0.45528
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4510 - accuracy: 0.7917 - val_loss: 0.4562 - val_accuracy: 0.7876 - lr: 0.0100
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7922
# Epoch 21: val_loss improved from 0.45528 to 0.45508, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4502 - accuracy: 0.7922 - val_loss: 0.4551 - val_accuracy: 0.7897 - lr: 1.0000e-03
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7922
# Epoch 22: val_loss did not improve from 0.45508
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4502 - accuracy: 0.7922 - val_loss: 0.4551 - val_accuracy: 0.7892 - lr: 1.0000e-03
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7923
# Epoch 23: val_loss improved from 0.45508 to 0.45506, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4502 - accuracy: 0.7923 - val_loss: 0.4551 - val_accuracy: 0.7901 - lr: 1.0000e-03
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7923
# Epoch 24: val_loss did not improve from 0.45506
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4502 - accuracy: 0.7923 - val_loss: 0.4551 - val_accuracy: 0.7901 - lr: 1.0000e-03
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.7923
# Epoch 25: val_loss did not improve from 0.45506
# 88854/88854 [==============================] - 107s 1ms/step - loss: 0.4501 - accuracy: 0.7923 - val_loss: 0.4551 - val_accuracy: 0.7891 - lr: 1.0000e-03
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.7923
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 26: val_loss did not improve from 0.45506
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4501 - accuracy: 0.7923 - val_loss: 0.4551 - val_accuracy: 0.7892 - lr: 1.0000e-03
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 27: val_loss improved from 0.45506 to 0.45506, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4551 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 28: val_loss improved from 0.45506 to 0.45505, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 29: val_loss improved from 0.45505 to 0.45504, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7897 - lr: 1.0000e-04
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 30: val_loss improved from 0.45504 to 0.45504, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7898 - lr: 1.0000e-04
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 31: val_loss did not improve from 0.45504
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 32: val_loss did not improve from 0.45504
# 88854/88854 [==============================] - 122s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7898 - lr: 1.0000e-05
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 33: val_loss improved from 0.45504 to 0.45504, saving model to models\m_tfidf_row_1.hdf5
# 88854/88854 [==============================] - 124s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7897 - lr: 1.0000e-05
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 34: val_loss did not improve from 0.45504
# 88854/88854 [==============================] - 124s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7897 - lr: 1.0000e-05
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7923
# Epoch 35: val_loss did not improve from 0.45504
# 88854/88854 [==============================] - 130s 1ms/step - loss: 0.4500 - accuracy: 0.7923 - val_loss: 0.4550 - val_accuracy: 0.7897 - lr: 1.0000e-06
# Epoch 35: early stopping
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 824us/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       177
#            1       0.77      0.84      0.80       182
#
#     accuracy                           0.79       359
#    macro avg       0.79      0.79      0.79       359
# weighted avg       0.79      0.79      0.79       359
#
# Accuracy: 0.7910863509749304
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: tfidf                                           ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.7639
# Epoch 1: val_loss improved from inf to 0.48022, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 140s 2ms/step - loss: 0.5125 - accuracy: 0.7639 - val_loss: 0.4802 - val_accuracy: 0.7779 - lr: 0.0100
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.7844
# Epoch 2: val_loss improved from 0.48022 to 0.46679, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 131s 1ms/step - loss: 0.4702 - accuracy: 0.7844 - val_loss: 0.4668 - val_accuracy: 0.7859 - lr: 0.0100
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4613 - accuracy: 0.7884
# Epoch 3: val_loss improved from 0.46679 to 0.46231, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 134s 2ms/step - loss: 0.4613 - accuracy: 0.7884 - val_loss: 0.4623 - val_accuracy: 0.7855 - lr: 0.0100
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4570 - accuracy: 0.7903
# Epoch 4: val_loss improved from 0.46231 to 0.45840, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 137s 2ms/step - loss: 0.4570 - accuracy: 0.7903 - val_loss: 0.4584 - val_accuracy: 0.7891 - lr: 0.0100
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.7915
# Epoch 5: val_loss improved from 0.45840 to 0.45669, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 138s 2ms/step - loss: 0.4544 - accuracy: 0.7915 - val_loss: 0.4567 - val_accuracy: 0.7898 - lr: 0.0100
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4527 - accuracy: 0.7921
# Epoch 6: val_loss improved from 0.45669 to 0.45555, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 141s 2ms/step - loss: 0.4527 - accuracy: 0.7921 - val_loss: 0.4556 - val_accuracy: 0.7912 - lr: 0.0100
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.7927
# Epoch 7: val_loss improved from 0.45555 to 0.45453, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 140s 2ms/step - loss: 0.4516 - accuracy: 0.7927 - val_loss: 0.4545 - val_accuracy: 0.7916 - lr: 0.0100
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.7928
# Epoch 8: val_loss improved from 0.45453 to 0.45388, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 148s 2ms/step - loss: 0.4507 - accuracy: 0.7928 - val_loss: 0.4539 - val_accuracy: 0.7905 - lr: 0.0100
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.7931
# Epoch 9: val_loss improved from 0.45388 to 0.45355, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 150s 2ms/step - loss: 0.4501 - accuracy: 0.7931 - val_loss: 0.4535 - val_accuracy: 0.7904 - lr: 0.0100
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.7931
# Epoch 10: val_loss improved from 0.45355 to 0.45310, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 152s 2ms/step - loss: 0.4496 - accuracy: 0.7931 - val_loss: 0.4531 - val_accuracy: 0.7907 - lr: 0.0100
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.7935
# Epoch 11: val_loss did not improve from 0.45310
# 88854/88854 [==============================] - 156s 2ms/step - loss: 0.4492 - accuracy: 0.7935 - val_loss: 0.4531 - val_accuracy: 0.7903 - lr: 0.0100
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.7934
# Epoch 12: val_loss did not improve from 0.45310
# 88854/88854 [==============================] - 163s 2ms/step - loss: 0.4489 - accuracy: 0.7934 - val_loss: 0.4536 - val_accuracy: 0.7922 - lr: 0.0100
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4487 - accuracy: 0.7938
# Epoch 13: val_loss improved from 0.45310 to 0.45250, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 160s 2ms/step - loss: 0.4487 - accuracy: 0.7938 - val_loss: 0.4525 - val_accuracy: 0.7917 - lr: 0.0100
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.7935
# Epoch 14: val_loss did not improve from 0.45250
# 88854/88854 [==============================] - 165s 2ms/step - loss: 0.4485 - accuracy: 0.7935 - val_loss: 0.4531 - val_accuracy: 0.7921 - lr: 0.0100
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.7937
# Epoch 15: val_loss improved from 0.45250 to 0.45241, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 170s 2ms/step - loss: 0.4483 - accuracy: 0.7937 - val_loss: 0.4524 - val_accuracy: 0.7904 - lr: 0.0100
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.7938
# Epoch 16: val_loss improved from 0.45241 to 0.45229, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 173s 2ms/step - loss: 0.4482 - accuracy: 0.7938 - val_loss: 0.4523 - val_accuracy: 0.7907 - lr: 0.0100
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.7938
# Epoch 17: val_loss improved from 0.45229 to 0.45204, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4481 - accuracy: 0.7938 - val_loss: 0.4520 - val_accuracy: 0.7913 - lr: 0.0100
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.7939
# Epoch 18: val_loss did not improve from 0.45204
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4480 - accuracy: 0.7939 - val_loss: 0.4521 - val_accuracy: 0.7921 - lr: 0.0100
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.7938
# Epoch 19: val_loss did not improve from 0.45204
# 88854/88854 [==============================] - 184s 2ms/step - loss: 0.4479 - accuracy: 0.7938 - val_loss: 0.4529 - val_accuracy: 0.7895 - lr: 0.0100
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.7939
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 20: val_loss did not improve from 0.45204
# 88854/88854 [==============================] - 182s 2ms/step - loss: 0.4478 - accuracy: 0.7939 - val_loss: 0.4528 - val_accuracy: 0.7895 - lr: 0.0100
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7945
# Epoch 21: val_loss improved from 0.45204 to 0.45187, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 181s 2ms/step - loss: 0.4470 - accuracy: 0.7945 - val_loss: 0.4519 - val_accuracy: 0.7914 - lr: 1.0000e-03
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7944
# Epoch 22: val_loss improved from 0.45187 to 0.45187, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 186s 2ms/step - loss: 0.4470 - accuracy: 0.7944 - val_loss: 0.4519 - val_accuracy: 0.7910 - lr: 1.0000e-03
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7944
# Epoch 23: val_loss improved from 0.45187 to 0.45185, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 192s 2ms/step - loss: 0.4470 - accuracy: 0.7944 - val_loss: 0.4519 - val_accuracy: 0.7914 - lr: 1.0000e-03
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.7944
# Epoch 24: val_loss did not improve from 0.45185
# 88854/88854 [==============================] - 188s 2ms/step - loss: 0.4470 - accuracy: 0.7944 - val_loss: 0.4519 - val_accuracy: 0.7920 - lr: 1.0000e-03
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4469 - accuracy: 0.7944
# Epoch 25: val_loss did not improve from 0.45185
# 88854/88854 [==============================] - 189s 2ms/step - loss: 0.4469 - accuracy: 0.7944 - val_loss: 0.4519 - val_accuracy: 0.7909 - lr: 1.0000e-03
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4469 - accuracy: 0.7945
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 26: val_loss did not improve from 0.45185
# 88854/88854 [==============================] - 205s 2ms/step - loss: 0.4469 - accuracy: 0.7945 - val_loss: 0.4519 - val_accuracy: 0.7908 - lr: 1.0000e-03
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 27: val_loss did not improve from 0.45185
# 88854/88854 [==============================] - 204s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4519 - val_accuracy: 0.7916 - lr: 1.0000e-04
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 28: val_loss improved from 0.45185 to 0.45184, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 207s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7914 - lr: 1.0000e-04
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 29: val_loss improved from 0.45184 to 0.45183, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 202s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7912 - lr: 1.0000e-04
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 30: val_loss did not improve from 0.45183
# 88854/88854 [==============================] - 214s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7912 - lr: 1.0000e-04
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 31: val_loss did not improve from 0.45183
# 88854/88854 [==============================] - 212s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7914 - lr: 1.0000e-04
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 32: val_loss did not improve from 0.45183
# 88854/88854 [==============================] - 217s 2ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7913 - lr: 1.0000e-05
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 33: val_loss improved from 0.45183 to 0.45183, saving model to models\m_tfidf_row_2.hdf5
# 88854/88854 [==============================] - 223s 3ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7912 - lr: 1.0000e-05
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 34: val_loss did not improve from 0.45183
# 88854/88854 [==============================] - 226s 3ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7912 - lr: 1.0000e-05
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4468 - accuracy: 0.7945
# Epoch 35: val_loss did not improve from 0.45183
# 88854/88854 [==============================] - 228s 3ms/step - loss: 0.4468 - accuracy: 0.7945 - val_loss: 0.4518 - val_accuracy: 0.7912 - lr: 1.0000e-06
# Epoch 35: early stopping
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       177
#            1       0.78      0.84      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.7994428969359332
# ╔═════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                    ║
# ║                              -------------------                                    ║
# ║                              Metric: tfidf                                          ║
# ║                              Preprocessing row: 3                                   ║
# ║                              Removing stop words: True                              ║
# ╚═════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_3.csv
# Load test data from data/csv_rows/test_row_3.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5356 - accuracy: 0.7452
# Epoch 1: val_loss improved from inf to 0.50665, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 243s 3ms/step - loss: 0.5356 - accuracy: 0.7452 - val_loss: 0.5067 - val_accuracy: 0.7603 - lr: 0.0100
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.7631
# Epoch 2: val_loss improved from 0.50665 to 0.49520, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 223s 3ms/step - loss: 0.4984 - accuracy: 0.7631 - val_loss: 0.4952 - val_accuracy: 0.7650 - lr: 0.0100
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.7662
# Epoch 3: val_loss improved from 0.49520 to 0.49179, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 239s 3ms/step - loss: 0.4908 - accuracy: 0.7662 - val_loss: 0.4918 - val_accuracy: 0.7645 - lr: 0.0100
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.7679
# Epoch 4: val_loss improved from 0.49179 to 0.48820, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 231s 3ms/step - loss: 0.4872 - accuracy: 0.7679 - val_loss: 0.4882 - val_accuracy: 0.7666 - lr: 0.0100
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.7684
# Epoch 5: val_loss improved from 0.48820 to 0.48710, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 240s 3ms/step - loss: 0.4851 - accuracy: 0.7684 - val_loss: 0.4871 - val_accuracy: 0.7669 - lr: 0.0100
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.7689
# Epoch 6: val_loss improved from 0.48710 to 0.48591, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 237s 3ms/step - loss: 0.4838 - accuracy: 0.7689 - val_loss: 0.4859 - val_accuracy: 0.7686 - lr: 0.0100
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4829 - accuracy: 0.7693
# Epoch 7: val_loss improved from 0.48591 to 0.48528, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 246s 3ms/step - loss: 0.4829 - accuracy: 0.7693 - val_loss: 0.4853 - val_accuracy: 0.7691 - lr: 0.0100
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4822 - accuracy: 0.7694
# Epoch 8: val_loss improved from 0.48528 to 0.48477, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 247s 3ms/step - loss: 0.4822 - accuracy: 0.7694 - val_loss: 0.4848 - val_accuracy: 0.7684 - lr: 0.0100
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.7695
# Epoch 9: val_loss improved from 0.48477 to 0.48445, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 255s 3ms/step - loss: 0.4818 - accuracy: 0.7695 - val_loss: 0.4845 - val_accuracy: 0.7682 - lr: 0.0100
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4814 - accuracy: 0.7696
# Epoch 10: val_loss improved from 0.48445 to 0.48432, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 246s 3ms/step - loss: 0.4814 - accuracy: 0.7696 - val_loss: 0.4843 - val_accuracy: 0.7680 - lr: 0.0100
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.7696
# Epoch 11: val_loss did not improve from 0.48432
# 88854/88854 [==============================] - 248s 3ms/step - loss: 0.4812 - accuracy: 0.7696 - val_loss: 0.4844 - val_accuracy: 0.7680 - lr: 0.0100
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.7699
# Epoch 12: val_loss did not improve from 0.48432
# 88854/88854 [==============================] - 247s 3ms/step - loss: 0.4810 - accuracy: 0.7699 - val_loss: 0.4851 - val_accuracy: 0.7687 - lr: 0.0100
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.7698
# Epoch 13: val_loss improved from 0.48432 to 0.48396, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 262s 3ms/step - loss: 0.4808 - accuracy: 0.7698 - val_loss: 0.4840 - val_accuracy: 0.7691 - lr: 0.0100
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.7696
# Epoch 14: val_loss did not improve from 0.48396
# 88854/88854 [==============================] - 256s 3ms/step - loss: 0.4807 - accuracy: 0.7696 - val_loss: 0.4848 - val_accuracy: 0.7690 - lr: 0.0100
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.7696
# Epoch 15: val_loss improved from 0.48396 to 0.48366, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 252s 3ms/step - loss: 0.4806 - accuracy: 0.7696 - val_loss: 0.4837 - val_accuracy: 0.7686 - lr: 0.0100
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.7697
# Epoch 16: val_loss did not improve from 0.48366
# 88854/88854 [==============================] - 259s 3ms/step - loss: 0.4805 - accuracy: 0.7697 - val_loss: 0.4839 - val_accuracy: 0.7682 - lr: 0.0100
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.7697
# Epoch 17: val_loss improved from 0.48366 to 0.48353, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 272s 3ms/step - loss: 0.4805 - accuracy: 0.7697 - val_loss: 0.4835 - val_accuracy: 0.7688 - lr: 0.0100
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7698
# Epoch 18: val_loss did not improve from 0.48353
# 88854/88854 [==============================] - 272s 3ms/step - loss: 0.4804 - accuracy: 0.7698 - val_loss: 0.4835 - val_accuracy: 0.7686 - lr: 0.0100
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.7700
# Epoch 19: val_loss did not improve from 0.48353
# 88854/88854 [==============================] - 268s 3ms/step - loss: 0.4803 - accuracy: 0.7700 - val_loss: 0.4842 - val_accuracy: 0.7677 - lr: 0.0100
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.7698
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 20: val_loss did not improve from 0.48353
# 88854/88854 [==============================] - 277s 3ms/step - loss: 0.4803 - accuracy: 0.7698 - val_loss: 0.4846 - val_accuracy: 0.7673 - lr: 0.0100
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7702
# Epoch 21: val_loss improved from 0.48353 to 0.48347, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 282s 3ms/step - loss: 0.4794 - accuracy: 0.7702 - val_loss: 0.4835 - val_accuracy: 0.7687 - lr: 1.0000e-03
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7703
# Epoch 22: val_loss improved from 0.48347 to 0.48346, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 282s 3ms/step - loss: 0.4794 - accuracy: 0.7703 - val_loss: 0.4835 - val_accuracy: 0.7687 - lr: 1.0000e-03
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7704
# Epoch 23: val_loss improved from 0.48346 to 0.48346, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 288s 3ms/step - loss: 0.4794 - accuracy: 0.7704 - val_loss: 0.4835 - val_accuracy: 0.7685 - lr: 1.0000e-03
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7702
# Epoch 24: val_loss did not improve from 0.48346
# 88854/88854 [==============================] - 287s 3ms/step - loss: 0.4794 - accuracy: 0.7702 - val_loss: 0.4836 - val_accuracy: 0.7690 - lr: 1.0000e-03
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7704
# Epoch 25: val_loss did not improve from 0.48346
# 88854/88854 [==============================] - 298s 3ms/step - loss: 0.4794 - accuracy: 0.7704 - val_loss: 0.4836 - val_accuracy: 0.7684 - lr: 1.0000e-03
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.7704
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 26: val_loss did not improve from 0.48346
# 88854/88854 [==============================] - 308s 3ms/step - loss: 0.4794 - accuracy: 0.7704 - val_loss: 0.4835 - val_accuracy: 0.7686 - lr: 1.0000e-03
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.7704
# Epoch 27: val_loss did not improve from 0.48346
# 88854/88854 [==============================] - 306s 3ms/step - loss: 0.4793 - accuracy: 0.7704 - val_loss: 0.4835 - val_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.7705
# Epoch 28: val_loss improved from 0.48346 to 0.48345, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 307s 3ms/step - loss: 0.4793 - accuracy: 0.7705 - val_loss: 0.4835 - val_accuracy: 0.7686 - lr: 1.0000e-04
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.7704
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 29: val_loss improved from 0.48345 to 0.48345, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 316s 4ms/step - loss: 0.4793 - accuracy: 0.7704 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-04
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 30: val_loss improved from 0.48345 to 0.48345, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 303s 3ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-05
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 31: val_loss improved from 0.48345 to 0.48345, saving model to models\m_tfidf_row_3.hdf5
# 88854/88854 [==============================] - 318s 4ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-05
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7704
# Epoch 32: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 304s 3ms/step - loss: 0.4792 - accuracy: 0.7704 - val_loss: 0.4834 - val_accuracy: 0.7687 - lr: 1.0000e-05
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 33: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 309s 3ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-05
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 34: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 322s 4ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-06
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7704
# Epoch 35: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 318s 4ms/step - loss: 0.4792 - accuracy: 0.7704 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-06
# Epoch 36/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 36: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 345s 4ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-06
# Epoch 37/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7705
# Epoch 37: val_loss did not improve from 0.48345
# 88854/88854 [==============================] - 341s 4ms/step - loss: 0.4792 - accuracy: 0.7705 - val_loss: 0.4834 - val_accuracy: 0.7688 - lr: 1.0000e-06
# Epoch 37: early stopping
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79       177
#            1       0.78      0.83      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.7966573816155988
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: tfidf                                           ║
# ║                              Preprocessing row: 4                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_4.csv
# Load test data from data/csv_rows/test_row_4.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.7644
# Epoch 1: val_loss improved from inf to 0.48059, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 374s 4ms/step - loss: 0.5115 - accuracy: 0.7644 - val_loss: 0.4806 - val_accuracy: 0.7783 - lr: 0.0100
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.7839
# Epoch 2: val_loss improved from 0.48059 to 0.46751, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 347s 4ms/step - loss: 0.4707 - accuracy: 0.7839 - val_loss: 0.4675 - val_accuracy: 0.7859 - lr: 0.0100
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7879
# Epoch 3: val_loss improved from 0.46751 to 0.46324, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 355s 4ms/step - loss: 0.4621 - accuracy: 0.7879 - val_loss: 0.4632 - val_accuracy: 0.7850 - lr: 0.0100
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.7898
# Epoch 4: val_loss improved from 0.46324 to 0.45921, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 357s 4ms/step - loss: 0.4578 - accuracy: 0.7898 - val_loss: 0.4592 - val_accuracy: 0.7891 - lr: 0.0100
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.7910
# Epoch 5: val_loss improved from 0.45921 to 0.45752, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 348s 4ms/step - loss: 0.4553 - accuracy: 0.7910 - val_loss: 0.4575 - val_accuracy: 0.7896 - lr: 0.0100
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.7917
# Epoch 6: val_loss improved from 0.45752 to 0.45641, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 354s 4ms/step - loss: 0.4537 - accuracy: 0.7917 - val_loss: 0.4564 - val_accuracy: 0.7910 - lr: 0.0100
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.7921
# Epoch 7: val_loss improved from 0.45641 to 0.45540, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 343s 4ms/step - loss: 0.4525 - accuracy: 0.7921 - val_loss: 0.4554 - val_accuracy: 0.7915 - lr: 0.0100
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4516 - accuracy: 0.7922
# Epoch 8: val_loss improved from 0.45540 to 0.45475, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 373s 4ms/step - loss: 0.4516 - accuracy: 0.7922 - val_loss: 0.4548 - val_accuracy: 0.7902 - lr: 0.0100
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.7924
# Epoch 9: val_loss improved from 0.45475 to 0.45440, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 382s 4ms/step - loss: 0.4510 - accuracy: 0.7924 - val_loss: 0.4544 - val_accuracy: 0.7900 - lr: 0.0100
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4506 - accuracy: 0.7926
# Epoch 10: val_loss improved from 0.45440 to 0.45397, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 377s 4ms/step - loss: 0.4506 - accuracy: 0.7926 - val_loss: 0.4540 - val_accuracy: 0.7906 - lr: 0.0100
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7929
# Epoch 11: val_loss did not improve from 0.45397
# 88854/88854 [==============================] - 370s 4ms/step - loss: 0.4502 - accuracy: 0.7929 - val_loss: 0.4540 - val_accuracy: 0.7902 - lr: 0.0100
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.7930
# Epoch 12: val_loss did not improve from 0.45397
# 88854/88854 [==============================] - 387s 4ms/step - loss: 0.4499 - accuracy: 0.7930 - val_loss: 0.4545 - val_accuracy: 0.7920 - lr: 0.0100
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.7933
# Epoch 13: val_loss improved from 0.45397 to 0.45336, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 385s 4ms/step - loss: 0.4496 - accuracy: 0.7933 - val_loss: 0.4534 - val_accuracy: 0.7912 - lr: 0.0100
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.7929
# Epoch 14: val_loss did not improve from 0.45336
# 88854/88854 [==============================] - 364s 4ms/step - loss: 0.4494 - accuracy: 0.7929 - val_loss: 0.4538 - val_accuracy: 0.7919 - lr: 0.0100
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4493 - accuracy: 0.7932
# Epoch 15: val_loss improved from 0.45336 to 0.45325, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 383s 4ms/step - loss: 0.4493 - accuracy: 0.7932 - val_loss: 0.4533 - val_accuracy: 0.7902 - lr: 0.0100
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.7932
# Epoch 16: val_loss improved from 0.45325 to 0.45318, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 400s 5ms/step - loss: 0.4492 - accuracy: 0.7932 - val_loss: 0.4532 - val_accuracy: 0.7905 - lr: 0.0100
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.7932
# Epoch 17: val_loss improved from 0.45318 to 0.45294, saving model to models\m_tfidf_row_4.hdf5
# ...
# Epoch 33: val_loss did not improve from 0.45271
# 88854/88854 [==============================] - 468s 5ms/step - loss: 0.4478 - accuracy: 0.7940 - val_loss: 0.4527 - val_accuracy: 0.7910 - lr: 1.0000e-05
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.7940
# Epoch 34: val_loss improved from 0.45271 to 0.45271, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 461s 5ms/step - loss: 0.4478 - accuracy: 0.7940 - val_loss: 0.4527 - val_accuracy: 0.7911 - lr: 1.0000e-05
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.7940
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 35: val_loss did not improve from 0.45271
# 88854/88854 [==============================] - 466s 5ms/step - loss: 0.4478 - accuracy: 0.7940 - val_loss: 0.4527 - val_accuracy: 0.7911 - lr: 1.0000e-05
# Epoch 36/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.7940
# Epoch 36: val_loss improved from 0.45271 to 0.45271, saving model to models\m_tfidf_row_4.hdf5
# 88854/88854 [==============================] - 471s 5ms/step - loss: 0.4478 - accuracy: 0.7940 - val_loss: 0.4527 - val_accuracy: 0.7911 - lr: 1.0000e-06
# Epoch 36: early stopping
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       177
#            1       0.77      0.83      0.80       182
#
#     accuracy                           0.79       359
#    macro avg       0.79      0.79      0.79       359
# weighted avg       0.79      0.79      0.79       359
#
# Accuracy: 0.7883008356545961
# ╔═════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                    ║
# ║                              -------------------                                    ║
# ║                              Metric: tfidf                                          ║
# ║                              Preprocessing row: 5                                   ║
# ║                              Removing stop words: True                              ║
# ╚═════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_5.csv
# Load test data from data/csv_rows/test_row_5.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5407 - accuracy: 0.7402
# Epoch 1: val_loss improved from inf to 0.51196, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 514s 6ms/step - loss: 0.5407 - accuracy: 0.7402 - val_loss: 0.5120 - val_accuracy: 0.7546 - lr: 0.0100
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5044 - accuracy: 0.7577
# Epoch 2: val_loss improved from 0.51196 to 0.50058, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 499s 6ms/step - loss: 0.5044 - accuracy: 0.7577 - val_loss: 0.5006 - val_accuracy: 0.7600 - lr: 0.0100
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4969 - accuracy: 0.7610
# Epoch 3: val_loss improved from 0.50058 to 0.49699, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 480s 5ms/step - loss: 0.4969 - accuracy: 0.7610 - val_loss: 0.4970 - val_accuracy: 0.7597 - lr: 0.0100
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7626
# Epoch 4: val_loss improved from 0.49699 to 0.49373, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 479s 5ms/step - loss: 0.4934 - accuracy: 0.7626 - val_loss: 0.4937 - val_accuracy: 0.7615 - lr: 0.0100
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7634
# Epoch 5: val_loss improved from 0.49373 to 0.49267, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 474s 5ms/step - loss: 0.4913 - accuracy: 0.7634 - val_loss: 0.4927 - val_accuracy: 0.7619 - lr: 0.0100
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.7639
# Epoch 6: val_loss improved from 0.49267 to 0.49150, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 508s 6ms/step - loss: 0.4900 - accuracy: 0.7639 - val_loss: 0.4915 - val_accuracy: 0.7633 - lr: 0.0100
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.7641
# Epoch 7: val_loss improved from 0.49150 to 0.49084, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 538s 6ms/step - loss: 0.4891 - accuracy: 0.7641 - val_loss: 0.4908 - val_accuracy: 0.7636 - lr: 0.0100
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4885 - accuracy: 0.7643
# Epoch 8: val_loss improved from 0.49084 to 0.49055, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 519s 6ms/step - loss: 0.4885 - accuracy: 0.7643 - val_loss: 0.4906 - val_accuracy: 0.7631 - lr: 0.0100
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4881 - accuracy: 0.7643
# Epoch 9: val_loss improved from 0.49055 to 0.49006, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 535s 6ms/step - loss: 0.4881 - accuracy: 0.7643 - val_loss: 0.4901 - val_accuracy: 0.7634 - lr: 0.0100
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4878 - accuracy: 0.7643
# Epoch 10: val_loss improved from 0.49006 to 0.48983, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 551s 6ms/step - loss: 0.4878 - accuracy: 0.7643 - val_loss: 0.4898 - val_accuracy: 0.7632 - lr: 0.0100
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.7643
# Epoch 11: val_loss did not improve from 0.48983
# 88854/88854 [==============================] - 567s 6ms/step - loss: 0.4875 - accuracy: 0.7643 - val_loss: 0.4901 - val_accuracy: 0.7631 - lr: 0.0100
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.7643
# Epoch 12: val_loss did not improve from 0.48983
# 88854/88854 [==============================] - 569s 6ms/step - loss: 0.4873 - accuracy: 0.7643 - val_loss: 0.4905 - val_accuracy: 0.7635 - lr: 0.0100
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.7646
# Epoch 13: val_loss improved from 0.48983 to 0.48966, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 597s 7ms/step - loss: 0.4871 - accuracy: 0.7646 - val_loss: 0.4897 - val_accuracy: 0.7639 - lr: 0.0100
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.7644
# Epoch 14: val_loss did not improve from 0.48966
# 88854/88854 [==============================] - 638s 7ms/step - loss: 0.4871 - accuracy: 0.7644 - val_loss: 0.4902 - val_accuracy: 0.7636 - lr: 0.0100
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4870 - accuracy: 0.7645
# Epoch 15: val_loss improved from 0.48966 to 0.48939, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 560s 6ms/step - loss: 0.4870 - accuracy: 0.7645 - val_loss: 0.4894 - val_accuracy: 0.7634 - lr: 0.0100
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4869 - accuracy: 0.7644
# Epoch 16: val_loss did not improve from 0.48939
# 88854/88854 [==============================] - 541s 6ms/step - loss: 0.4869 - accuracy: 0.7644 - val_loss: 0.4895 - val_accuracy: 0.7633 - lr: 0.0100
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.7644
# Epoch 17: val_loss improved from 0.48939 to 0.48923, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 531s 6ms/step - loss: 0.4868 - accuracy: 0.7644 - val_loss: 0.4892 - val_accuracy: 0.7635 - lr: 0.0100
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.7646
# Epoch 18: val_loss improved from 0.48923 to 0.48921, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 576s 6ms/step - loss: 0.4868 - accuracy: 0.7646 - val_loss: 0.4892 - val_accuracy: 0.7634 - lr: 0.0100
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7648
# Epoch 19: val_loss did not improve from 0.48921
# 88854/88854 [==============================] - 562s 6ms/step - loss: 0.4867 - accuracy: 0.7648 - val_loss: 0.4898 - val_accuracy: 0.7628 - lr: 0.0100
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7646
# Epoch 20: val_loss did not improve from 0.48921
# 88854/88854 [==============================] - 532s 6ms/step - loss: 0.4867 - accuracy: 0.7646 - val_loss: 0.4900 - val_accuracy: 0.7626 - lr: 0.0100
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7644
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 21: val_loss did not improve from 0.48921
# 88854/88854 [==============================] - 532s 6ms/step - loss: 0.4867 - accuracy: 0.7644 - val_loss: 0.4893 - val_accuracy: 0.7635 - lr: 0.0100
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.7649
# Epoch 22: val_loss improved from 0.48921 to 0.48918, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 584s 7ms/step - loss: 0.4858 - accuracy: 0.7649 - val_loss: 0.4892 - val_accuracy: 0.7635 - lr: 1.0000e-03
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7651
# Epoch 23: val_loss improved from 0.48918 to 0.48916, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 652s 7ms/step - loss: 0.4857 - accuracy: 0.7651 - val_loss: 0.4892 - val_accuracy: 0.7634 - lr: 1.0000e-03
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7650
# Epoch 24: val_loss did not improve from 0.48916
# 88854/88854 [==============================] - 598s 7ms/step - loss: 0.4857 - accuracy: 0.7650 - val_loss: 0.4893 - val_accuracy: 0.7638 - lr: 1.0000e-03
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7650
# Epoch 25: val_loss did not improve from 0.48916
# 88854/88854 [==============================] - 643s 7ms/step - loss: 0.4857 - accuracy: 0.7650 - val_loss: 0.4893 - val_accuracy: 0.7632 - lr: 1.0000e-03
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7650
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 26: val_loss did not improve from 0.48916
# 88854/88854 [==============================] - 578s 7ms/step - loss: 0.4857 - accuracy: 0.7650 - val_loss: 0.4892 - val_accuracy: 0.7633 - lr: 1.0000e-03
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 27: val_loss improved from 0.48916 to 0.48915, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 599s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4892 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7649
# Epoch 28: val_loss improved from 0.48915 to 0.48913, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 566s 6ms/step - loss: 0.4856 - accuracy: 0.7649 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 29: val_loss improved from 0.48913 to 0.48913, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 585s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 30: val_loss improved from 0.48913 to 0.48912, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 611s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 31: val_loss did not improve from 0.48912
# 88854/88854 [==============================] - 653s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7633 - lr: 1.0000e-04
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 32: val_loss did not improve from 0.48912
# 88854/88854 [==============================] - 682s 8ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-05
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 33: val_loss improved from 0.48912 to 0.48912, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 619s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-05
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 34: val_loss improved from 0.48912 to 0.48912, saving model to models\m_tfidf_row_5.hdf5
# 88854/88854 [==============================] - 629s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-05
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.7650
# Epoch 35: val_loss did not improve from 0.48912
# 88854/88854 [==============================] - 628s 7ms/step - loss: 0.4856 - accuracy: 0.7650 - val_loss: 0.4891 - val_accuracy: 0.7634 - lr: 1.0000e-06
# Epoch 35: early stopping
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       177
#            1       0.79      0.82      0.80       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.7966573816155988
