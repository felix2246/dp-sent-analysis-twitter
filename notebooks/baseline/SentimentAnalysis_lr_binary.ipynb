# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
from sklearn.metrics import classification_report, accuracy_score, plot_confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
import keras
import tensorflow_privacy.privacy.optimizers as optimizers
import gc
from tensorflow.keras import backend as k

import warnings
warnings.filterwarnings('ignore')
#tf.compat.v1.disable_v2_behavior()

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 200
LEARNING_RATE = 1e-3
N = 1579634
N_TRAINING = 1421664
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def build_lr_model_DP():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(1, activation='sigmoid',
                    input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=optimizers.dp_optimizer_keras.DPKerasSGDOptimizer(
            l2_norm_clip=1,
            noise_multiplier=0.795,
            num_microbatches=BATCH_SIZE,
            learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)
    
    #callbacks
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                                     patience=3, min_lr=1e-6, verbose=1, min_delta=1e-5)

    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="models/m_%s_row_%d.hdf5" % (metric, preprocessing_row),
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')

    es = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                          patience=7,
                                          verbose=1,
                                          mode="min",
                                          min_delta=1e-5)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(len(y_train) / BATCH_SIZE), epochs=MAX_EPOCHS,
                                  use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[reduce_lr, checkpoint, es])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    save_history_to_file(
        history, "models/histories/history_%s_row_%d.csv" % (metric, preprocessing_row))
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/m_%s_row_%d.hdf5" %
                                            (metric, preprocessing_row))
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)
        
    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)

    #leave out 6 samples because length has to be divisible by BATCH_SIZE (limitation by tensorflow privacy)
    leave_out_samples_X = X_train[-6:]
    leave_out_samples_y = y_train[-6:]
    X_train = X_train[:-6]
    y_train = y_train[:-6]
    
    #train LR Model
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test,
                      X_val=X_val, y_val=y_val, metric=metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
for i in range(1, 6):  # [1,2,3,4,5]
    # Rows 3 and 5 expect removal of stopwords
    remove_stop_words = True if i in [3, 5] else False
    sentiment_analysis(remove_stop_words, metric= "binary", preprocessing_row=i)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: binary                                          ║
# ║                              Preprocessing row: 1                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_1.csv
# Load test data from data/csv_rows/test_row_1.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.7471
# Epoch 1: val_loss improved from inf to 0.50829, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.5367 - accuracy: 0.7471 - val_loss: 0.5083 - val_accuracy: 0.7648 - lr: 0.0010
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4978 - accuracy: 0.7714
# Epoch 2: val_loss improved from 0.50829 to 0.49412, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4978 - accuracy: 0.7714 - val_loss: 0.4941 - val_accuracy: 0.7743 - lr: 0.0010
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4880 - accuracy: 0.7772
# Epoch 3: val_loss improved from 0.49412 to 0.48772, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4880 - accuracy: 0.7772 - val_loss: 0.4877 - val_accuracy: 0.7785 - lr: 0.0010
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.7804
# Epoch 4: val_loss improved from 0.48772 to 0.48361, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4826 - accuracy: 0.7804 - val_loss: 0.4836 - val_accuracy: 0.7796 - lr: 0.0010
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.7826
# Epoch 5: val_loss improved from 0.48361 to 0.48095, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4791 - accuracy: 0.7826 - val_loss: 0.4810 - val_accuracy: 0.7802 - lr: 0.0010
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4766 - accuracy: 0.7840
# Epoch 6: val_loss improved from 0.48095 to 0.47886, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4766 - accuracy: 0.7840 - val_loss: 0.4789 - val_accuracy: 0.7828 - lr: 0.0010
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.7853
# Epoch 7: val_loss improved from 0.47886 to 0.47731, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4747 - accuracy: 0.7853 - val_loss: 0.4773 - val_accuracy: 0.7840 - lr: 0.0010
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.7860
# Epoch 8: val_loss improved from 0.47731 to 0.47596, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4732 - accuracy: 0.7860 - val_loss: 0.4760 - val_accuracy: 0.7849 - lr: 0.0010
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4720 - accuracy: 0.7867
# Epoch 9: val_loss improved from 0.47596 to 0.47498, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4720 - accuracy: 0.7867 - val_loss: 0.4750 - val_accuracy: 0.7858 - lr: 0.0010
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.7874
# Epoch 10: val_loss improved from 0.47498 to 0.47427, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4710 - accuracy: 0.7874 - val_loss: 0.4743 - val_accuracy: 0.7856 - lr: 0.0010
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.7877
# Epoch 11: val_loss improved from 0.47427 to 0.47387, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4702 - accuracy: 0.7877 - val_loss: 0.4739 - val_accuracy: 0.7849 - lr: 0.0010
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.7883
# Epoch 12: val_loss improved from 0.47387 to 0.47314, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4695 - accuracy: 0.7883 - val_loss: 0.4731 - val_accuracy: 0.7867 - lr: 0.0010
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.7885
# Epoch 13: val_loss improved from 0.47314 to 0.47267, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4689 - accuracy: 0.7885 - val_loss: 0.4727 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.7887
# Epoch 14: val_loss improved from 0.47267 to 0.47261, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4684 - accuracy: 0.7887 - val_loss: 0.4726 - val_accuracy: 0.7883 - lr: 0.0010
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.7889
# Epoch 15: val_loss improved from 0.47261 to 0.47182, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4679 - accuracy: 0.7889 - val_loss: 0.4718 - val_accuracy: 0.7872 - lr: 0.0010
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7892
# Epoch 16: val_loss improved from 0.47182 to 0.47149, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4675 - accuracy: 0.7892 - val_loss: 0.4715 - val_accuracy: 0.7873 - lr: 0.0010
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7894
# Epoch 17: val_loss improved from 0.47149 to 0.47110, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4672 - accuracy: 0.7894 - val_loss: 0.4711 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.7896
# Epoch 18: val_loss improved from 0.47110 to 0.47095, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4668 - accuracy: 0.7896 - val_loss: 0.4709 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4666 - accuracy: 0.7897
# Epoch 19: val_loss improved from 0.47095 to 0.47074, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4666 - accuracy: 0.7897 - val_loss: 0.4707 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.7899
# Epoch 20: val_loss did not improve from 0.47074
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4663 - accuracy: 0.7899 - val_loss: 0.4708 - val_accuracy: 0.7863 - lr: 0.0010
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7901
# Epoch 21: val_loss improved from 0.47074 to 0.47043, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4661 - accuracy: 0.7901 - val_loss: 0.4704 - val_accuracy: 0.7883 - lr: 0.0010
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.7900
# Epoch 22: val_loss improved from 0.47043 to 0.47018, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4659 - accuracy: 0.7900 - val_loss: 0.4702 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.7901
# Epoch 23: val_loss improved from 0.47018 to 0.47016, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4657 - accuracy: 0.7901 - val_loss: 0.4702 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.7903
# Epoch 24: val_loss improved from 0.47016 to 0.47014, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4656 - accuracy: 0.7903 - val_loss: 0.4701 - val_accuracy: 0.7883 - lr: 0.0010
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.7902
# Epoch 25: val_loss improved from 0.47014 to 0.47008, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4654 - accuracy: 0.7902 - val_loss: 0.4701 - val_accuracy: 0.7868 - lr: 0.0010
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.7904
# Epoch 26: val_loss improved from 0.47008 to 0.46987, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4653 - accuracy: 0.7904 - val_loss: 0.4699 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7903
# Epoch 27: val_loss improved from 0.46987 to 0.46969, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4652 - accuracy: 0.7903 - val_loss: 0.4697 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4651 - accuracy: 0.7905
# Epoch 28: val_loss improved from 0.46969 to 0.46959, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4651 - accuracy: 0.7905 - val_loss: 0.4696 - val_accuracy: 0.7880 - lr: 0.0010
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7905
# Epoch 29: val_loss improved from 0.46959 to 0.46953, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4649 - accuracy: 0.7905 - val_loss: 0.4695 - val_accuracy: 0.7883 - lr: 0.0010
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7907
# Epoch 30: val_loss improved from 0.46953 to 0.46947, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4649 - accuracy: 0.7907 - val_loss: 0.4695 - val_accuracy: 0.7881 - lr: 0.0010
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.7906
# Epoch 31: val_loss improved from 0.46947 to 0.46938, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4648 - accuracy: 0.7906 - val_loss: 0.4694 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.7907
# Epoch 32: val_loss did not improve from 0.46938
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4647 - accuracy: 0.7907 - val_loss: 0.4695 - val_accuracy: 0.7877 - lr: 0.0010
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4646 - accuracy: 0.7907
# Epoch 33: val_loss did not improve from 0.46938
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4646 - accuracy: 0.7907 - val_loss: 0.4695 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4646 - accuracy: 0.7908
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 34: val_loss did not improve from 0.46938
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4646 - accuracy: 0.7908 - val_loss: 0.4694 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.7911
# Epoch 35: val_loss improved from 0.46938 to 0.46920, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4641 - accuracy: 0.7911 - val_loss: 0.4692 - val_accuracy: 0.7880 - lr: 1.0000e-04
# Epoch 36/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7911
# Epoch 36: val_loss improved from 0.46920 to 0.46918, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4640 - accuracy: 0.7911 - val_loss: 0.4692 - val_accuracy: 0.7880 - lr: 1.0000e-04
# Epoch 37/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7911
# Epoch 37: val_loss improved from 0.46918 to 0.46915, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4640 - accuracy: 0.7911 - val_loss: 0.4692 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 38/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7911
# Epoch 38: val_loss improved from 0.46915 to 0.46915, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4640 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7880 - lr: 1.0000e-04
# Epoch 39/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7912
# Epoch 39: val_loss improved from 0.46915 to 0.46914, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4640 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 40/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7912
# Epoch 40: val_loss improved from 0.46914 to 0.46914, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4640 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7880 - lr: 1.0000e-04
# Epoch 41/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7911
# Epoch 41: val_loss improved from 0.46914 to 0.46912, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4640 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 42/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7911
# Epoch 42: val_loss improved from 0.46912 to 0.46911, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4640 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7881 - lr: 1.0000e-04
# Epoch 43/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7911
# Epoch 43: val_loss improved from 0.46911 to 0.46911, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4639 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7881 - lr: 1.0000e-04
# Epoch 44/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7911
# Epoch 44: val_loss improved from 0.46911 to 0.46909, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4639 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 45/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7912
# Epoch 45: val_loss did not improve from 0.46909
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4639 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7884 - lr: 1.0000e-04
# Epoch 46/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7912
# Epoch 46: val_loss did not improve from 0.46909
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4639 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7881 - lr: 1.0000e-04
# Epoch 47/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7912
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 47: val_loss did not improve from 0.46909
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4639 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7881 - lr: 1.0000e-04
# Epoch 48/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7911
# Epoch 48: val_loss improved from 0.46909 to 0.46909, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4639 - accuracy: 0.7911 - val_loss: 0.4691 - val_accuracy: 0.7883 - lr: 1.0000e-05
# Epoch 49/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7912
# Epoch 49: val_loss improved from 0.46909 to 0.46909, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4639 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7883 - lr: 1.0000e-05
# Epoch 50/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7912
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 50: val_loss improved from 0.46909 to 0.46909, saving model to models\m_binary_row_1.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4639 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7883 - lr: 1.0000e-05
# Epoch 51/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7912
# Epoch 51: val_loss did not improve from 0.46909
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4638 - accuracy: 0.7912 - val_loss: 0.4691 - val_accuracy: 0.7883 - lr: 1.0000e-06
# Epoch 51: early stopping
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       177
#            1       0.78      0.85      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.7994428969359332
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: binary                                          ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.7482
# Epoch 1: val_loss improved from inf to 0.50203, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 107s 1ms/step - loss: 0.5298 - accuracy: 0.7482 - val_loss: 0.5020 - val_accuracy: 0.7684 - lr: 0.0010
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7748
# Epoch 2: val_loss improved from 0.50203 to 0.48828, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4919 - accuracy: 0.7748 - val_loss: 0.4883 - val_accuracy: 0.7777 - lr: 0.0010
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4824 - accuracy: 0.7807
# Epoch 3: val_loss improved from 0.48828 to 0.48211, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4824 - accuracy: 0.7807 - val_loss: 0.4821 - val_accuracy: 0.7811 - lr: 0.0010
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.7836
# Epoch 4: val_loss improved from 0.48211 to 0.47819, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4772 - accuracy: 0.7836 - val_loss: 0.4782 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4738 - accuracy: 0.7855
# Epoch 5: val_loss improved from 0.47819 to 0.47566, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4738 - accuracy: 0.7855 - val_loss: 0.4757 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4714 - accuracy: 0.7868
# Epoch 6: val_loss improved from 0.47566 to 0.47361, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4714 - accuracy: 0.7868 - val_loss: 0.4736 - val_accuracy: 0.7853 - lr: 0.0010
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.7879
# Epoch 7: val_loss improved from 0.47361 to 0.47213, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4695 - accuracy: 0.7879 - val_loss: 0.4721 - val_accuracy: 0.7859 - lr: 0.0010
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.7887
# Epoch 8: val_loss improved from 0.47213 to 0.47086, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4681 - accuracy: 0.7887 - val_loss: 0.4709 - val_accuracy: 0.7865 - lr: 0.0010
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.7893
# Epoch 9: val_loss improved from 0.47086 to 0.46989, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4669 - accuracy: 0.7893 - val_loss: 0.4699 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.7899
# Epoch 10: val_loss improved from 0.46989 to 0.46923, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4660 - accuracy: 0.7899 - val_loss: 0.4692 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7904
# Epoch 11: val_loss improved from 0.46923 to 0.46894, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4652 - accuracy: 0.7904 - val_loss: 0.4689 - val_accuracy: 0.7865 - lr: 0.0010
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4645 - accuracy: 0.7909
# Epoch 12: val_loss improved from 0.46894 to 0.46818, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4645 - accuracy: 0.7909 - val_loss: 0.4682 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7910
# Epoch 13: val_loss improved from 0.46818 to 0.46772, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4639 - accuracy: 0.7910 - val_loss: 0.4677 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.7914
# Epoch 14: val_loss improved from 0.46772 to 0.46771, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4634 - accuracy: 0.7914 - val_loss: 0.4677 - val_accuracy: 0.7898 - lr: 0.0010
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.7918
# Epoch 15: val_loss improved from 0.46771 to 0.46690, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4630 - accuracy: 0.7918 - val_loss: 0.4669 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4626 - accuracy: 0.7920
# Epoch 16: val_loss improved from 0.46690 to 0.46661, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4626 - accuracy: 0.7920 - val_loss: 0.4666 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4623 - accuracy: 0.7921
# Epoch 17: val_loss improved from 0.46661 to 0.46620, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4623 - accuracy: 0.7921 - val_loss: 0.4662 - val_accuracy: 0.7889 - lr: 0.0010
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7923
# Epoch 18: val_loss improved from 0.46620 to 0.46605, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4620 - accuracy: 0.7923 - val_loss: 0.4661 - val_accuracy: 0.7893 - lr: 0.0010
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.7925
# Epoch 19: val_loss improved from 0.46605 to 0.46594, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4617 - accuracy: 0.7925 - val_loss: 0.4659 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.7927
# Epoch 20: val_loss did not improve from 0.46594
# 88854/88854 [==============================] - 109s 1ms/step - loss: 0.4615 - accuracy: 0.7927 - val_loss: 0.4660 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4613 - accuracy: 0.7928
# Epoch 21: val_loss improved from 0.46594 to 0.46557, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4613 - accuracy: 0.7928 - val_loss: 0.4656 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4611 - accuracy: 0.7928
# Epoch 22: val_loss improved from 0.46557 to 0.46533, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4611 - accuracy: 0.7928 - val_loss: 0.4653 - val_accuracy: 0.7893 - lr: 0.0010
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4609 - accuracy: 0.7930
# Epoch 23: val_loss improved from 0.46533 to 0.46530, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4609 - accuracy: 0.7930 - val_loss: 0.4653 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.7930
# Epoch 24: val_loss did not improve from 0.46530
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4607 - accuracy: 0.7930 - val_loss: 0.4653 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.7931
# Epoch 25: val_loss did not improve from 0.46530
# 88854/88854 [==============================] - 109s 1ms/step - loss: 0.4606 - accuracy: 0.7931 - val_loss: 0.4654 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.7932
# Epoch 26: val_loss improved from 0.46530 to 0.46508, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4605 - accuracy: 0.7932 - val_loss: 0.4651 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.7932
# Epoch 27: val_loss improved from 0.46508 to 0.46487, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4604 - accuracy: 0.7932 - val_loss: 0.4649 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.7932
# Epoch 28: val_loss improved from 0.46487 to 0.46478, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 111s 1ms/step - loss: 0.4602 - accuracy: 0.7932 - val_loss: 0.4648 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.7934
# Epoch 29: val_loss improved from 0.46478 to 0.46473, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4601 - accuracy: 0.7934 - val_loss: 0.4647 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7934
# Epoch 30: val_loss improved from 0.46473 to 0.46464, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4600 - accuracy: 0.7934 - val_loss: 0.4646 - val_accuracy: 0.7901 - lr: 0.0010
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7934
# Epoch 31: val_loss improved from 0.46464 to 0.46456, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 111s 1ms/step - loss: 0.4600 - accuracy: 0.7934 - val_loss: 0.4646 - val_accuracy: 0.7905 - lr: 0.0010
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4599 - accuracy: 0.7935
# Epoch 32: val_loss did not improve from 0.46456
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.4599 - accuracy: 0.7935 - val_loss: 0.4647 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.7935
# Epoch 33: val_loss did not improve from 0.46456
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4598 - accuracy: 0.7935 - val_loss: 0.4646 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.7936
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 34: val_loss did not improve from 0.46456
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4598 - accuracy: 0.7936 - val_loss: 0.4646 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.7939
# Epoch 35: val_loss improved from 0.46456 to 0.46437, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4592 - accuracy: 0.7939 - val_loss: 0.4644 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 36/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.7940
# Epoch 36: val_loss improved from 0.46437 to 0.46435, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 117s 1ms/step - loss: 0.4592 - accuracy: 0.7940 - val_loss: 0.4643 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 37/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.7940
# Epoch 37: val_loss improved from 0.46435 to 0.46432, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4592 - accuracy: 0.7940 - val_loss: 0.4643 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 38/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.7941
# Epoch 38: val_loss improved from 0.46432 to 0.46432, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4592 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 39/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7942
# Epoch 39: val_loss improved from 0.46432 to 0.46431, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4591 - accuracy: 0.7942 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 40/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7940
# Epoch 40: val_loss did not improve from 0.46431
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4591 - accuracy: 0.7940 - val_loss: 0.4643 - val_accuracy: 0.7896 - lr: 1.0000e-04
# Epoch 41/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7940
# Epoch 41: val_loss improved from 0.46431 to 0.46429, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 121s 1ms/step - loss: 0.4591 - accuracy: 0.7940 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 42/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 42: val_loss improved from 0.46429 to 0.46428, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 118s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 43/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 43: val_loss improved from 0.46428 to 0.46428, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 44/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 44: val_loss improved from 0.46428 to 0.46426, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 114s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 45/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 45: val_loss did not improve from 0.46426
# 88854/88854 [==============================] - 111s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 46/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 46: val_loss did not improve from 0.46426
# 88854/88854 [==============================] - 114s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 47/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7941
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 47: val_loss did not improve from 0.46426
# 88854/88854 [==============================] - 116s 1ms/step - loss: 0.4591 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 48/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.7941
# Epoch 48: val_loss improved from 0.46426 to 0.46426, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4590 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 49/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.7941
# Epoch 49: val_loss improved from 0.46426 to 0.46426, saving model to models\m_binary_row_2.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4590 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-05
# Epoch 50/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.7941
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 50: val_loss did not improve from 0.46426
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4590 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-05
# Epoch 51/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.7941
# Epoch 51: val_loss did not improve from 0.46426
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4590 - accuracy: 0.7941 - val_loss: 0.4643 - val_accuracy: 0.7903 - lr: 1.0000e-06
# Epoch 51: early stopping
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       177
#            1       0.78      0.85      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.8022284122562674
# ╔═════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                    ║
# ║                              -------------------                                    ║
# ║                              Metric: binary                                         ║
# ║                              Preprocessing row: 3                                   ║
# ║                              Removing stop words: True                              ║
# ╚═════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_3.csv
# Load test data from data/csv_rows/test_row_3.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5577 - accuracy: 0.7173
# Epoch 1: val_loss improved from inf to 0.52940, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 120s 1ms/step - loss: 0.5577 - accuracy: 0.7173 - val_loss: 0.5294 - val_accuracy: 0.7432 - lr: 0.0010
# Epoch 2/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7491
# Epoch 2: val_loss improved from 0.52940 to 0.51529, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.5197 - accuracy: 0.7491 - val_loss: 0.5153 - val_accuracy: 0.7537 - lr: 0.0010
# Epoch 3/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.7562
# Epoch 3: val_loss improved from 0.51529 to 0.50880, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.5098 - accuracy: 0.7562 - val_loss: 0.5088 - val_accuracy: 0.7574 - lr: 0.0010
# Epoch 4/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5044 - accuracy: 0.7600
# Epoch 4: val_loss improved from 0.50880 to 0.50473, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 114s 1ms/step - loss: 0.5044 - accuracy: 0.7600 - val_loss: 0.5047 - val_accuracy: 0.7602 - lr: 0.0010
# Epoch 5/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7623
# Epoch 5: val_loss improved from 0.50473 to 0.50211, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.5009 - accuracy: 0.7623 - val_loss: 0.5021 - val_accuracy: 0.7613 - lr: 0.0010
# Epoch 6/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.7642
# Epoch 6: val_loss improved from 0.50211 to 0.49995, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4984 - accuracy: 0.7642 - val_loss: 0.4999 - val_accuracy: 0.7628 - lr: 0.0010
# Epoch 7/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7654
# Epoch 7: val_loss improved from 0.49995 to 0.49836, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 120s 1ms/step - loss: 0.4965 - accuracy: 0.7654 - val_loss: 0.4984 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 8/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4950 - accuracy: 0.7663
# Epoch 8: val_loss improved from 0.49836 to 0.49714, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 116s 1ms/step - loss: 0.4950 - accuracy: 0.7663 - val_loss: 0.4971 - val_accuracy: 0.7648 - lr: 0.0010
# Epoch 9/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7672
# Epoch 9: val_loss improved from 0.49714 to 0.49615, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4938 - accuracy: 0.7672 - val_loss: 0.4962 - val_accuracy: 0.7655 - lr: 0.0010
# Epoch 10/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7677
# Epoch 10: val_loss improved from 0.49615 to 0.49536, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4928 - accuracy: 0.7677 - val_loss: 0.4954 - val_accuracy: 0.7658 - lr: 0.0010
# Epoch 11/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7682
# Epoch 11: val_loss improved from 0.49536 to 0.49504, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 118s 1ms/step - loss: 0.4920 - accuracy: 0.7682 - val_loss: 0.4950 - val_accuracy: 0.7654 - lr: 0.0010
# Epoch 12/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7687
# Epoch 12: val_loss improved from 0.49504 to 0.49417, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 114s 1ms/step - loss: 0.4913 - accuracy: 0.7687 - val_loss: 0.4942 - val_accuracy: 0.7668 - lr: 0.0010
# Epoch 13/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7691
# Epoch 13: val_loss improved from 0.49417 to 0.49370, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4907 - accuracy: 0.7691 - val_loss: 0.4937 - val_accuracy: 0.7672 - lr: 0.0010
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4902 - accuracy: 0.7693
# Epoch 14: val_loss improved from 0.49370 to 0.49352, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 111s 1ms/step - loss: 0.4902 - accuracy: 0.7693 - val_loss: 0.4935 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.7696
# Epoch 15: val_loss improved from 0.49352 to 0.49290, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4897 - accuracy: 0.7696 - val_loss: 0.4929 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.7698
# Epoch 16: val_loss improved from 0.49290 to 0.49259, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.4893 - accuracy: 0.7698 - val_loss: 0.4926 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.7701
# Epoch 17: val_loss improved from 0.49259 to 0.49223, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 125s 1ms/step - loss: 0.4890 - accuracy: 0.7701 - val_loss: 0.4922 - val_accuracy: 0.7675 - lr: 0.0010
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.7702
# Epoch 18: val_loss improved from 0.49223 to 0.49205, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 117s 1ms/step - loss: 0.4887 - accuracy: 0.7702 - val_loss: 0.4921 - val_accuracy: 0.7675 - lr: 0.0010
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.7705
# Epoch 19: val_loss improved from 0.49205 to 0.49185, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 117s 1ms/step - loss: 0.4884 - accuracy: 0.7705 - val_loss: 0.4918 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4881 - accuracy: 0.7706
# Epoch 20: val_loss improved from 0.49185 to 0.49178, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 117s 1ms/step - loss: 0.4881 - accuracy: 0.7706 - val_loss: 0.4918 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.7707
# Epoch 21: val_loss improved from 0.49178 to 0.49148, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 114s 1ms/step - loss: 0.4879 - accuracy: 0.7707 - val_loss: 0.4915 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.7708
# Epoch 22: val_loss improved from 0.49148 to 0.49128, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.4877 - accuracy: 0.7708 - val_loss: 0.4913 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.7709
# Epoch 23: val_loss improved from 0.49128 to 0.49116, saving model to models\m_binary_row_3.hdf5
# 88854/88854 [==============================] - 121s 1ms/step - loss: 0.4875 - accuracy: 0.7709 - val_loss: 0.4912 - val_accuracy: 0.7684 - lr: 0.0010
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.7711
# Epoch 24: val_loss did not improve from 0.49116
# 88854/88854 [==============================] - 119s 1ms/step - loss: 0.4874 - accuracy: 0.7711 - val_loss: 0.4912 - val_accuracy: 0.7691 - lr: 0.0010
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.7711
# ...
# Epoch 14/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.7642
# Epoch 14: val_loss improved from 0.49855 to 0.49832, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4955 - accuracy: 0.7642 - val_loss: 0.4983 - val_accuracy: 0.7623 - lr: 0.0010
# Epoch 15/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4951 - accuracy: 0.7644
# Epoch 15: val_loss improved from 0.49832 to 0.49773, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 192s 2ms/step - loss: 0.4951 - accuracy: 0.7644 - val_loss: 0.4977 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 16/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7647
# Epoch 16: val_loss improved from 0.49773 to 0.49741, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 193s 2ms/step - loss: 0.4947 - accuracy: 0.7647 - val_loss: 0.4974 - val_accuracy: 0.7631 - lr: 0.0010
# Epoch 17/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.7650
# Epoch 17: val_loss improved from 0.49741 to 0.49704, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 190s 2ms/step - loss: 0.4943 - accuracy: 0.7650 - val_loss: 0.4970 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 18/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7652
# Epoch 18: val_loss improved from 0.49704 to 0.49688, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 193s 2ms/step - loss: 0.4940 - accuracy: 0.7652 - val_loss: 0.4969 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 19/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4937 - accuracy: 0.7653
# Epoch 19: val_loss improved from 0.49688 to 0.49666, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 194s 2ms/step - loss: 0.4937 - accuracy: 0.7653 - val_loss: 0.4967 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 20/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.7654
# Epoch 20: val_loss improved from 0.49666 to 0.49651, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 195s 2ms/step - loss: 0.4935 - accuracy: 0.7654 - val_loss: 0.4965 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 21/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7655
# Epoch 21: val_loss improved from 0.49651 to 0.49629, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 196s 2ms/step - loss: 0.4932 - accuracy: 0.7655 - val_loss: 0.4963 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 22/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.7655
# Epoch 22: val_loss improved from 0.49629 to 0.49607, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 195s 2ms/step - loss: 0.4930 - accuracy: 0.7655 - val_loss: 0.4961 - val_accuracy: 0.7635 - lr: 0.0010
# Epoch 23/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7657
# Epoch 23: val_loss improved from 0.49607 to 0.49596, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 196s 2ms/step - loss: 0.4929 - accuracy: 0.7657 - val_loss: 0.4960 - val_accuracy: 0.7635 - lr: 0.0010
# Epoch 24/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4927 - accuracy: 0.7658
# Epoch 24: val_loss did not improve from 0.49596
# 88854/88854 [==============================] - 196s 2ms/step - loss: 0.4927 - accuracy: 0.7658 - val_loss: 0.4960 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 25/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.7659
# Epoch 25: val_loss did not improve from 0.49596
# 88854/88854 [==============================] - 195s 2ms/step - loss: 0.4925 - accuracy: 0.7659 - val_loss: 0.4960 - val_accuracy: 0.7632 - lr: 0.0010
# Epoch 26/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4924 - accuracy: 0.7660
# Epoch 26: val_loss improved from 0.49596 to 0.49573, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 197s 2ms/step - loss: 0.4924 - accuracy: 0.7660 - val_loss: 0.4957 - val_accuracy: 0.7637 - lr: 0.0010
# Epoch 27/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.7660
# Epoch 27: val_loss improved from 0.49573 to 0.49561, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 197s 2ms/step - loss: 0.4923 - accuracy: 0.7660 - val_loss: 0.4956 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 28/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.7661
# Epoch 28: val_loss improved from 0.49561 to 0.49543, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 197s 2ms/step - loss: 0.4922 - accuracy: 0.7661 - val_loss: 0.4954 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 29/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7662
# Epoch 29: val_loss improved from 0.49543 to 0.49540, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 194s 2ms/step - loss: 0.4920 - accuracy: 0.7662 - val_loss: 0.4954 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 30/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7663
# Epoch 30: val_loss improved from 0.49540 to 0.49531, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 200s 2ms/step - loss: 0.4919 - accuracy: 0.7663 - val_loss: 0.4953 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 31/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7664
# Epoch 31: val_loss improved from 0.49531 to 0.49523, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 200s 2ms/step - loss: 0.4919 - accuracy: 0.7664 - val_loss: 0.4952 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 32/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4918 - accuracy: 0.7663
# Epoch 32: val_loss improved from 0.49523 to 0.49522, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 196s 2ms/step - loss: 0.4918 - accuracy: 0.7663 - val_loss: 0.4952 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 33/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.7663
# Epoch 33: val_loss improved from 0.49522 to 0.49514, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 198s 2ms/step - loss: 0.4917 - accuracy: 0.7663 - val_loss: 0.4951 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 34/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.7664
# Epoch 34: val_loss did not improve from 0.49514
# 88854/88854 [==============================] - 210s 2ms/step - loss: 0.4916 - accuracy: 0.7664 - val_loss: 0.4951 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 35/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.7664
# Epoch 35: val_loss did not improve from 0.49514
# 88854/88854 [==============================] - 201s 2ms/step - loss: 0.4916 - accuracy: 0.7664 - val_loss: 0.4952 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 36/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.7664
# Epoch 36: val_loss improved from 0.49514 to 0.49500, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 197s 2ms/step - loss: 0.4915 - accuracy: 0.7664 - val_loss: 0.4950 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 37/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.7665
# Epoch 37: val_loss improved from 0.49500 to 0.49493, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 195s 2ms/step - loss: 0.4914 - accuracy: 0.7665 - val_loss: 0.4949 - val_accuracy: 0.7645 - lr: 0.0010
# Epoch 38/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.7666
# Epoch 38: val_loss improved from 0.49493 to 0.49491, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 182s 2ms/step - loss: 0.4914 - accuracy: 0.7666 - val_loss: 0.4949 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 39/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7665
# Epoch 39: val_loss improved from 0.49491 to 0.49484, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 167s 2ms/step - loss: 0.4913 - accuracy: 0.7665 - val_loss: 0.4948 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 40/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7667
# Epoch 40: val_loss did not improve from 0.49484
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4913 - accuracy: 0.7667 - val_loss: 0.4951 - val_accuracy: 0.7638 - lr: 0.0010
# Epoch 41/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4912 - accuracy: 0.7666
# Epoch 41: val_loss did not improve from 0.49484
# 88854/88854 [==============================] - 199s 2ms/step - loss: 0.4912 - accuracy: 0.7666 - val_loss: 0.4948 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 42/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4912 - accuracy: 0.7666
# Epoch 42: val_loss improved from 0.49484 to 0.49476, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 187s 2ms/step - loss: 0.4912 - accuracy: 0.7666 - val_loss: 0.4948 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 43/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4912 - accuracy: 0.7667
# Epoch 43: val_loss did not improve from 0.49476
# 88854/88854 [==============================] - 192s 2ms/step - loss: 0.4912 - accuracy: 0.7667 - val_loss: 0.4949 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 44/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4911 - accuracy: 0.7666
# Epoch 44: val_loss did not improve from 0.49476
# 88854/88854 [==============================] - 197s 2ms/step - loss: 0.4911 - accuracy: 0.7666 - val_loss: 0.4948 - val_accuracy: 0.7651 - lr: 0.0010
# Epoch 45/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4911 - accuracy: 0.7666
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 45: val_loss did not improve from 0.49476
# 88854/88854 [==============================] - 182s 2ms/step - loss: 0.4911 - accuracy: 0.7666 - val_loss: 0.4948 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 46/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.7669
# Epoch 46: val_loss improved from 0.49476 to 0.49473, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 193s 2ms/step - loss: 0.4908 - accuracy: 0.7669 - val_loss: 0.4947 - val_accuracy: 0.7648 - lr: 1.0000e-04
# Epoch 47/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 47: val_loss improved from 0.49473 to 0.49472, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7646 - lr: 1.0000e-04
# Epoch 48/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7669
# Epoch 48: val_loss improved from 0.49472 to 0.49471, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4907 - accuracy: 0.7669 - val_loss: 0.4947 - val_accuracy: 0.7648 - lr: 1.0000e-04
# Epoch 49/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 49: val_loss improved from 0.49471 to 0.49471, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 193s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7647 - lr: 1.0000e-04
# Epoch 50/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7669
# Epoch 50: val_loss improved from 0.49471 to 0.49470, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 196s 2ms/step - loss: 0.4907 - accuracy: 0.7669 - val_loss: 0.4947 - val_accuracy: 0.7648 - lr: 1.0000e-04
# Epoch 51/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 51: val_loss did not improve from 0.49470
# 88854/88854 [==============================] - 188s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7647 - lr: 1.0000e-04
# Epoch 52/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7669
# Epoch 52: val_loss did not improve from 0.49470
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4907 - accuracy: 0.7669 - val_loss: 0.4947 - val_accuracy: 0.7648 - lr: 1.0000e-04
# Epoch 53/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 53: val_loss did not improve from 0.49470
# 88854/88854 [==============================] - 185s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7645 - lr: 1.0000e-04
# Epoch 54/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 54: val_loss did not improve from 0.49470
# 88854/88854 [==============================] - 185s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7647 - lr: 1.0000e-05
# Epoch 55/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 55: val_loss improved from 0.49470 to 0.49469, saving model to models\m_binary_row_5.hdf5
# 88854/88854 [==============================] - 184s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7647 - lr: 1.0000e-05
# Epoch 56/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 56: val_loss did not improve from 0.49469
# 88854/88854 [==============================] - 185s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7646 - lr: 1.0000e-05
# Epoch 57/200
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7670
# Epoch 57: val_loss did not improve from 0.49469
# 88854/88854 [==============================] - 189s 2ms/step - loss: 0.4907 - accuracy: 0.7670 - val_loss: 0.4947 - val_accuracy: 0.7646 - lr: 1.0000e-06
# Epoch 57: early stopping
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       177
#            1       0.78      0.82      0.80       182
#
#     accuracy                           0.79       359
#    macro avg       0.79      0.79      0.79       359
# weighted avg       0.79      0.79      0.79       359
#
# Accuracy: 0.7883008356545961
