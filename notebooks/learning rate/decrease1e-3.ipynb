# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import gc

import warnings
warnings.filterwarnings('ignore')

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 100
LEARNING_RATE = 1e-3
N = 1579634
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)
    
    #callbacks
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                                     patience=3, min_lr=1e-6, verbose=1, min_delta=1e-5)

    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='models/best_model_1e-3.hdf5',
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')

    es = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                          patience=7,
                                          verbose=1,
                                          mode="min",
                                          min_delta=1e-5)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(len(y_train) / BATCH_SIZE), epochs=MAX_EPOCHS,
                                  use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[reduce_lr, checkpoint, es])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    save_history_to_file(history, "models/histories/history_1e-3.csv")
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/best_model_1e-3.hdf5")
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)

    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)

    #leave out 6 samples because length has to be divisible by BATCH_SIZE (limitation by tensorflow privacy)
    leave_out_samples_X = X_train[-6:]
    leave_out_samples_y = y_train[-6:]
    X_train = X_train[:-6]
    y_train = y_train[:-6]
    
    #train LR
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val, metric= metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
sentiment_analysis(remove_stop_words=False, metric = "count", preprocessing_row = 2)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: count                                           ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5303 - accuracy: 0.7505
# Epoch 1: val_loss improved from inf to 0.50337, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 87s 974us/step - loss: 0.5303 - accuracy: 0.7505 - val_loss: 0.5034 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 2/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7758
# Epoch 2: val_loss improved from 0.50337 to 0.48993, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 91s 1ms/step - loss: 0.4934 - accuracy: 0.7758 - val_loss: 0.4899 - val_accuracy: 0.7780 - lr: 0.0010
# Epoch 3/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.7813
# Epoch 3: val_loss improved from 0.48993 to 0.48390, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4840 - accuracy: 0.7813 - val_loss: 0.4839 - val_accuracy: 0.7816 - lr: 0.0010
# Epoch 4/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.7840
# Epoch 4: val_loss improved from 0.48390 to 0.48004, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4790 - accuracy: 0.7840 - val_loss: 0.4800 - val_accuracy: 0.7829 - lr: 0.0010
# Epoch 5/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.7860
# Epoch 5: val_loss improved from 0.48004 to 0.47751, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4757 - accuracy: 0.7860 - val_loss: 0.4775 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 6/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7874
# Epoch 6: val_loss improved from 0.47751 to 0.47560, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4733 - accuracy: 0.7874 - val_loss: 0.4756 - val_accuracy: 0.7856 - lr: 0.0010
# Epoch 7/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.7883
# Epoch 7: val_loss improved from 0.47560 to 0.47418, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4715 - accuracy: 0.7883 - val_loss: 0.4742 - val_accuracy: 0.7862 - lr: 0.0010
# Epoch 8/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4701 - accuracy: 0.7891
# Epoch 8: val_loss improved from 0.47418 to 0.47288, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4701 - accuracy: 0.7891 - val_loss: 0.4729 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 9/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.7896
# Epoch 9: val_loss improved from 0.47288 to 0.47195, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4690 - accuracy: 0.7896 - val_loss: 0.4720 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 10/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.7901
# Epoch 10: val_loss improved from 0.47195 to 0.47131, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4681 - accuracy: 0.7901 - val_loss: 0.4713 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 11/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.7906
# Epoch 11: val_loss improved from 0.47131 to 0.47097, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4673 - accuracy: 0.7906 - val_loss: 0.4710 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 12/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.7911
# Epoch 12: val_loss improved from 0.47097 to 0.47047, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4667 - accuracy: 0.7911 - val_loss: 0.4705 - val_accuracy: 0.7890 - lr: 0.0010
# Epoch 13/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7912
# Epoch 13: val_loss improved from 0.47047 to 0.46990, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4661 - accuracy: 0.7912 - val_loss: 0.4699 - val_accuracy: 0.7887 - lr: 0.0010
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.7916
# Epoch 14: val_loss did not improve from 0.46990
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4656 - accuracy: 0.7916 - val_loss: 0.4700 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7918
# Epoch 15: val_loss improved from 0.46990 to 0.46911, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4652 - accuracy: 0.7918 - val_loss: 0.4691 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.7921
# Epoch 16: val_loss improved from 0.46911 to 0.46882, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4648 - accuracy: 0.7921 - val_loss: 0.4688 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4645 - accuracy: 0.7923
# Epoch 17: val_loss improved from 0.46882 to 0.46841, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4645 - accuracy: 0.7923 - val_loss: 0.4684 - val_accuracy: 0.7893 - lr: 0.0010
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4642 - accuracy: 0.7923
# Epoch 18: val_loss improved from 0.46841 to 0.46830, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4642 - accuracy: 0.7923 - val_loss: 0.4683 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7925
# Epoch 19: val_loss improved from 0.46830 to 0.46826, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4640 - accuracy: 0.7925 - val_loss: 0.4683 - val_accuracy: 0.7889 - lr: 0.0010
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7928
# Epoch 20: val_loss improved from 0.46826 to 0.46825, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4638 - accuracy: 0.7928 - val_loss: 0.4682 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 21/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.7928
# Epoch 21: val_loss improved from 0.46825 to 0.46788, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4636 - accuracy: 0.7928 - val_loss: 0.4679 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 22/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.7928
# Epoch 22: val_loss improved from 0.46788 to 0.46762, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4634 - accuracy: 0.7928 - val_loss: 0.4676 - val_accuracy: 0.7896 - lr: 0.0010
# Epoch 23/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.7929
# Epoch 23: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4632 - accuracy: 0.7929 - val_loss: 0.4677 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 24/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.7931
# Epoch 24: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4630 - accuracy: 0.7931 - val_loss: 0.4676 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 25/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4629 - accuracy: 0.7931
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 25: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4629 - accuracy: 0.7931 - val_loss: 0.4677 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 26/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4623 - accuracy: 0.7936
# Epoch 26: val_loss improved from 0.46762 to 0.46716, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4623 - accuracy: 0.7936 - val_loss: 0.4672 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 27/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 27: val_loss did not improve from 0.46716
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4672 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 28/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7937
# Epoch 28: val_loss improved from 0.46716 to 0.46713, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 102s 1ms/step - loss: 0.4622 - accuracy: 0.7937 - val_loss: 0.4671 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 29/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 29: val_loss improved from 0.46713 to 0.46710, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 30/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 30: val_loss improved from 0.46710 to 0.46709, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 31/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 31: val_loss improved from 0.46709 to 0.46709, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7906 - lr: 1.0000e-04
# Epoch 32/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7937
# Epoch 32: val_loss improved from 0.46709 to 0.46707, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4622 - accuracy: 0.7937 - val_loss: 0.4671 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 33/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 33: val_loss improved from 0.46707 to 0.46707, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 34/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7936
# Epoch 34: val_loss improved from 0.46707 to 0.46704, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4621 - accuracy: 0.7936 - val_loss: 0.4670 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 35/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 35: val_loss did not improve from 0.46704
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 36/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 36: val_loss improved from 0.46704 to 0.46704, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 107s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 37/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 37: val_loss improved from 0.46704 to 0.46702, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 38/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 38: val_loss improved from 0.46702 to 0.46702, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 39/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 39: val_loss improved from 0.46702 to 0.46701, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 40/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 40: val_loss did not improve from 0.46701
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7896 - lr: 1.0000e-04
# Epoch 41/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7936
# Epoch 41: val_loss improved from 0.46701 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4620 - accuracy: 0.7936 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 42/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 42: val_loss improved from 0.46699 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 43/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 43: val_loss improved from 0.46699 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7905 - lr: 1.0000e-05
# Epoch 44/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7937
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 44: val_loss improved from 0.46699 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4620 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 45/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 45: val_loss improved from 0.46699 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 46/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 46: val_loss improved from 0.46699 to 0.46699, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 47/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 47: val_loss improved from 0.46699 to 0.46698, saving model to models\best_model_1e-3.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 48/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 48: val_loss did not improve from 0.46698
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 48: early stopping
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       177
#            1       0.78      0.85      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.81      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.8022284122562674
