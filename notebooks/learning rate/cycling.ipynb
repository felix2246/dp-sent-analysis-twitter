# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import gc

import warnings
warnings.filterwarnings('ignore')

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 100
LEARNING_RATE = 1e-2
N = 1579634
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
# cycle learning rates
base_lr = 1e-4
max_lr = 1e-2
step_size = 2

def cycle_scheduler(epoch, lr):
    cycle = math.floor(1 + epoch / (2 * step_size))
    x = abs(epoch / step_size - 2 * cycle + 1)
    new_lr = base_lr + (max_lr - base_lr) * max(0, (1-x))
    return new_lr

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

def plot_acc_learningrate(history):
    plt.plot(history.history['lr'],
             history.history['accuracy'], label="train")
    plt.plot(history.history['lr'],
             history.history['val_accuracy'], label="test")
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('learning rate')
    plt.xscale('log')
    plt.show()


def plot_loss_learningrate(history):
    plt.plot(history.history['lr'],
             history.history['loss'], label="train")
    plt.plot(history.history['lr'],
             history.history['val_loss'], label="test")
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('learning rate')
    plt.xscale('log')
    plt.show()


def plot_lr_cycle(history):
    plt.plot(range(1, len(history.history['lr'])+1),
             history.history['lr'], color="#6cb95c")
    plt.title('learning rate per epoch')
    plt.ylabel('learning rate')
    plt.xlabel('epoch')
    plt.ylim(base_lr, max_lr)
    plt.yscale('symlog')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)

    #callback
    schedule_lr = tf.keras.callbacks.LearningRateScheduler(
        cycle_scheduler, verbose=1)

    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                                     patience=3, min_lr=1e-6, verbose=1, min_delta=1e-5)

    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='models/best_model_cycle.hdf5',
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')

    es = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                          patience=7,
                                          verbose=1,
                                          mode="min",
                                          min_delta=1e-5)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(len(y_train) / BATCH_SIZE), epochs=MAX_EPOCHS,
                        use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[schedule_lr, checkpoint, es])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    #save_history_to_file(history, "models/histories/history_%s_row_%d.csv" % (metric, preprocessing_row))
    save_history_to_file(history, "models/histories/history_cycling.csv")
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)
    plot_lr_cycle(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/best_model_cycle.hdf5")
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)

    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)

    #leave out 6 samples because length has to be divisible by BATCH_SIZE (limitation by tensorflow privacy)
    leave_out_samples_X = X_train[-6:]
    leave_out_samples_y = y_train[-6:]
    X_train = X_train[:-6]
    y_train = y_train[:-6]
    
    #train LR
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val, metric= metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
sentiment_analysis(remove_stop_words=False, metric = "count", preprocessing_row = 2)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: count                                           ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.6073 - accuracy: 0.6856
# Epoch 1: val_loss improved from inf to 0.57454, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.6073 - accuracy: 0.6856 - val_loss: 0.5745 - val_accuracy: 0.7206 - lr: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 2/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7753
# Epoch 2: val_loss improved from 0.57454 to 0.47817, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4920 - accuracy: 0.7753 - val_loss: 0.4782 - val_accuracy: 0.7844 - lr: 0.0050
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.01.
# Epoch 3/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7865
# Epoch 3: val_loss improved from 0.47817 to 0.47287, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4733 - accuracy: 0.7865 - val_loss: 0.4729 - val_accuracy: 0.7842 - lr: 0.0100
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 4/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.7906
# Epoch 4: val_loss improved from 0.47287 to 0.46988, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4667 - accuracy: 0.7906 - val_loss: 0.4699 - val_accuracy: 0.7870 - lr: 0.0050
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 5/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7924
# Epoch 5: val_loss improved from 0.46988 to 0.46818, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4638 - accuracy: 0.7924 - val_loss: 0.4682 - val_accuracy: 0.7895 - lr: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 6/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4655 - accuracy: 0.7913
# Epoch 6: val_loss did not improve from 0.46818
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4655 - accuracy: 0.7913 - val_loss: 0.4693 - val_accuracy: 0.7898 - lr: 0.0050
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.01.
# Epoch 7/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7900
# Epoch 7: val_loss did not improve from 0.46818
# 88854/88854 [==============================] - 88s 995us/step - loss: 0.4675 - accuracy: 0.7900 - val_loss: 0.4704 - val_accuracy: 0.7883 - lr: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 8/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.7919
# Epoch 8: val_loss improved from 0.46818 to 0.46814, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.4644 - accuracy: 0.7919 - val_loss: 0.4681 - val_accuracy: 0.7891 - lr: 0.0050
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4619 - accuracy: 0.7933
# Epoch 9: val_loss improved from 0.46814 to 0.46701, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 91s 1ms/step - loss: 0.4619 - accuracy: 0.7933 - val_loss: 0.4670 - val_accuracy: 0.7899 - lr: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 10/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.7919
# Epoch 10: val_loss did not improve from 0.46701
# 88854/88854 [==============================] - 89s 997us/step - loss: 0.4641 - accuracy: 0.7919 - val_loss: 0.4677 - val_accuracy: 0.7891 - lr: 0.0050
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.01.
# Epoch 11/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.7902
# Epoch 11: val_loss did not improve from 0.46701
# 88854/88854 [==============================] - 88s 992us/step - loss: 0.4667 - accuracy: 0.7902 - val_loss: 0.4702 - val_accuracy: 0.7875 - lr: 0.0100
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 12/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7920
# Epoch 12: val_loss did not improve from 0.46701
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.4639 - accuracy: 0.7920 - val_loss: 0.4689 - val_accuracy: 0.7904 - lr: 0.0050
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 13/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.7934
# Epoch 13: val_loss improved from 0.46701 to 0.46680, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4615 - accuracy: 0.7934 - val_loss: 0.4668 - val_accuracy: 0.7903 - lr: 1.0000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.7923
# Epoch 14: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4637 - accuracy: 0.7923 - val_loss: 0.4688 - val_accuracy: 0.7909 - lr: 0.0050
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.01.
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.7903
# Epoch 15: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4664 - accuracy: 0.7903 - val_loss: 0.4703 - val_accuracy: 0.7866 - lr: 0.0100
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.7923
# Epoch 16: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4637 - accuracy: 0.7923 - val_loss: 0.4682 - val_accuracy: 0.7887 - lr: 0.0050
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4614 - accuracy: 0.7936
# Epoch 17: val_loss improved from 0.46680 to 0.46680, saving model to models\best_model_cycle.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4614 - accuracy: 0.7936 - val_loss: 0.4668 - val_accuracy: 0.7908 - lr: 1.0000e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.7921
# Epoch 18: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 89s 1ms/step - loss: 0.4636 - accuracy: 0.7921 - val_loss: 0.4682 - val_accuracy: 0.7905 - lr: 0.0050
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.01.
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.7904
# Epoch 19: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 91s 1ms/step - loss: 0.4664 - accuracy: 0.7904 - val_loss: 0.4722 - val_accuracy: 0.7844 - lr: 0.0100
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.005050000000000001.
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.7923
# Epoch 20: val_loss did not improve from 0.46680
# 88854/88854 [==============================] - 89s 1ms/step - loss: 0.4637 - accuracy: 0.7923 - val_loss: 0.4688 - val_accuracy: 0.7873 - lr: 0.0050
# Epoch 20: early stopping
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       177
#            1       0.78      0.85      0.82       182
#
#     accuracy                           0.81       359
#    macro avg       0.81      0.80      0.80       359
# weighted avg       0.81      0.81      0.80       359
#
# Accuracy: 0.8050139275766016
