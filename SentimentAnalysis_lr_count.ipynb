# %%
import pandas as pd
import numpy as np
import random
import json
import math
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
from sklearn.metrics import classification_report, accuracy_score, plot_confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import tensorflow as tf
import keras
import tensorflow_privacy.privacy.optimizers as optimizers
import gc
from tensorflow.keras import backend as k

import warnings
warnings.filterwarnings('ignore')
#tf.compat.v1.disable_v2_behavior()

# %%
def set_random_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)

# %%
FILES_DIRECTORY = 'data/csv_rows/'
MAX_EPOCHS = 100
LEARNING_RATE = 1e-3
N = 1579634
NUMBER_OF_FEATURES = 5000
BATCH_SIZE = 16

# %%
def print_msg_box(msg, indent=1, width=None, title=None):
    """Print message-box with optional title."""
    lines = msg.split('\n')
    space = " " * indent
    if not width:
        width = max(map(len, lines))
    box = f'╔{"═" * (width + indent * 2)}╗\n'  # upper_border
    if title:
        box += f'║{space}{title:<{width}}{space}║\n'  # title
        box += f'║{space}{"-" * len(title):<{width}}{space}║\n'  # underscore
    box += ''.join([f'║{space}{line:<{width}}{space}║\n' for line in lines])
    box += f'╚{"═" * (width + indent * 2)}╝'  # lower_border
    print(box)

# %% [markdown]
# # Create bow model

# %%
def shuffle_data(data):
    set_random_seeds(42)
    data = data.sample(frac=1).reset_index(drop=True)
    return data

# %%
f_stopwords = open('stopwords.json')
stopwords_list = json.load(f_stopwords)

# %%
def create_bow_model(train_data, test_data, metric: str, remove_stop_words: bool):
    #stop words removal
    stop_words = None
    if (remove_stop_words == True):
        stop_words = stopwords_list

    token_pattern = r"(?u)\b\w\w+\b"

    #create model with given metric
    bow = None
    if (metric == 'count'):
        bow = CountVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'tfidf'):
        bow = TfidfVectorizer(
            max_features=NUMBER_OF_FEATURES, stop_words=stop_words, token_pattern=token_pattern)
    elif (metric == 'binary'):
        bow = CountVectorizer(max_features=NUMBER_OF_FEATURES, stop_words=stop_words,
                              binary=True, token_pattern=token_pattern)
    else:
        raise ValueError("metric must be either %s or %s or %s!" %
                         ('<count>', '<tfidf>', '<binary>'))

    #create data partititions
    X_train = bow.fit_transform(train_data['content'])
    y_train = train_data['polarity']
    X_test = bow.transform(test_data['content'])
    y_test = test_data['polarity']

    return (X_train, y_train, X_test, y_test)

# %% [markdown]
# # Train models

# %% [markdown]
# ## Logistic Regression

# %%
def unison_shuffled_copies(a, b):
    assert a.shape[0] == len(b)
    shuffler = np.random.permutation(a.shape[0])
    return a[shuffler], b[shuffler]

# %%
def build_lr_model_baseline():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(
        1, activation='sigmoid', input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def build_lr_model_DP():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(1, activation='sigmoid',
                    input_dim=NUMBER_OF_FEATURES))
    loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.losses.Reduction.NONE)
    model.compile(
        optimizer=optimizers.dp_optimizer_keras.DPKerasSGDOptimizer(
            l2_norm_clip=1,
            noise_multiplier=0.795,
            num_microbatches=BATCH_SIZE,
            learning_rate=LEARNING_RATE),
        loss=loss,
        metrics=['accuracy'])
    return model

# %%
def plot_training_loss(history):
    #take average loss of each epoch
    history.history['loss'] = [(lambda x: np.mean(x))(x)
                               for x in history.history['loss']]
    history.history['val_loss'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['val_loss']]

    # summarize history for loss
    plt.plot(range(1, len(history.history['loss'])+1),
             history.history['loss'], label="train")
    plt.plot(range(1, len(history.history['val_loss'])+1),
             history.history['val_loss'], label="test")
    plt.title('model loss')
    plt.legend()
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def plot_training_acc(history):
    #take average loss of each epoch
    history.history['accuracy'] = [(lambda x: np.mean(x))(x)
                                   for x in history.history['accuracy']]
    history.history['val_accuracy'] = [(lambda x: np.mean(x))(x)
                                       for x in history.history['val_accuracy']]

    # summarize history for acc
    plt.plot(range(1, len(history.history['accuracy'])+1),
             history.history['accuracy'], label="train")
    plt.plot(range(1, len(history.history['val_accuracy'])+1),
             history.history['val_accuracy'], label="test")
    plt.title('model accuracy')
    plt.legend()
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()

# %%
def evaluate_model(model, test_X, test_y):
    yhat = model.predict(test_X)

    yhat[yhat < 0.5] = 0
    yhat[yhat >= 0.5] = 1

    acc = accuracy_score(test_y, yhat)
    print(classification_report(test_y, yhat))
    print('Accuracy: ' + str(acc))
    
    return acc

# %%
def save_history_to_file(history, file):
    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(file)

# %%
def generate_batches_shuffled(X_train_bow, y_train_bow):
    set_random_seeds(42)
    while True:
        #shuffle before each epoch
        X_train_bow, y_train_bow = unison_shuffled_copies(
            X_train_bow, y_train_bow)
        for j in range(0, X_train_bow.shape[0], BATCH_SIZE):
            x_batch = X_train_bow[j: j+BATCH_SIZE, :].todense()
            y_batch = y_train_bow[j: j+BATCH_SIZE]
            yield (x_batch, y_batch)

        gc.collect()

# %%
def train(model, X_train, y_train, X_val, y_val, preprocessing_row, metric):
    set_random_seeds(42)

    print("\n")
    print_msg_box('Logistic Regression:', indent=10)
    
    #callbacks
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                                                     patience=3, min_lr=1e-6, verbose=1, min_delta=1e-5)

    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="models/m_%s_row_%d.hdf5" % (metric, preprocessing_row),
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')

    es = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                          patience=7,
                                          verbose=1,
                                          mode="min",
                                          min_delta=1e-5)

    #train
    history = model.fit_generator(generate_batches_shuffled(X_train, y_train), steps_per_epoch=math.ceil(len(y_train) / BATCH_SIZE), epochs=MAX_EPOCHS,
                                  use_multiprocessing=False, shuffle=True, validation_data=(X_val.todense(), y_val), callbacks=[reduce_lr, checkpoint, es])
    print(model.summary())
    return history

# %%
def train_LR(X_train, y_train, X_test, y_test, X_val, y_val, metric, preprocessing_row):

    lr_model = build_lr_model_baseline()
    history = train(lr_model, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val, preprocessing_row=preprocessing_row, metric=metric)
    
    save_history_to_file(
        history, "models/histories/history_%s_row_%d.csv" % (metric, preprocessing_row))
    
    #plots
    plot_training_loss(history)
    plot_training_acc(history)

    #Load and evaluate the best LR model version discovered during training
    best_model = tf.keras.models.load_model("models/m_%s_row_%d.hdf5" %
                                            (metric, preprocessing_row))
    return evaluate_model(best_model, X_test.todense(), y_test)

# %% [markdown]
# # Main function

# %%
def sentiment_analysis(remove_stop_words: bool, metric: str, preprocessing_row: int):

    msg = "Metric: %s\n" \
            "Preprocessing row: %d\n" \
            "Removing stop words: %s" % (metric, preprocessing_row, remove_stop_words)

    print_msg_box(msg=msg, indent=30, title='Sentiment Analysis:')

    #load train data
    print("\nLoad train data from %strain_row_%d.csv" %
          (FILES_DIRECTORY, preprocessing_row))
    train_data = pd.read_csv("%strain_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    train_data['content'] = train_data['content'].values.astype('str')
    
    #shuffle train data
    train_data = shuffle_data(train_data)

    #load test data
    print("Load test data from %stest_row_%d.csv\n" % (FILES_DIRECTORY, preprocessing_row))
    test_data = pd.read_csv("%stest_row_%d.csv" % (FILES_DIRECTORY, preprocessing_row))
    
    #create bow model
    X_train, y_train, X_test, y_test = create_bow_model(
        train_data=train_data, test_data=test_data, metric=metric, remove_stop_words=remove_stop_words)
        
    #reshape label vectors
    y_train[y_train == 4] = 1
    y_train = y_train.values.reshape(-1, 1)
    y_test[y_test == 4] = 1
    y_test = y_test.values.reshape(-1, 1)

    #split into train and validation data
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42)

    #leave out 6 samples because length has to be divisible by BATCH_SIZE (limitation by tensorflow privacy)
    leave_out_samples_X = X_train[-6:]
    leave_out_samples_y = y_train[-6:]
    X_train = X_train[:-6]
    y_train = y_train[:-6]
    
    #train LR Model
    acc_lr = train_LR(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test,
                      X_val=X_val, y_val=y_val, metric=metric, preprocessing_row=preprocessing_row)

# %% [markdown]
# # Execution

# %%
for i in range(1, 6):  # [1,2,3,4,5]
    # Rows 3 and 5 expect removal of stopwords
    remove_stop_words = True if i in [3, 5] else False
    sentiment_analysis(remove_stop_words, metric= "count", preprocessing_row=i)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: count                                           ║
# ║                              Preprocessing row: 1                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_1.csv
# Load test data from data/csv_rows/test_row_1.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5372 - accuracy: 0.7479
# Epoch 1: val_loss improved from inf to 0.50947, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.5372 - accuracy: 0.7479 - val_loss: 0.5095 - val_accuracy: 0.7649 - lr: 0.0010
# Epoch 2/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.7719
# Epoch 2: val_loss improved from 0.50947 to 0.49561, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4992 - accuracy: 0.7719 - val_loss: 0.4956 - val_accuracy: 0.7744 - lr: 0.0010
# Epoch 3/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4896 - accuracy: 0.7776
# Epoch 3: val_loss improved from 0.49561 to 0.48940, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4896 - accuracy: 0.7776 - val_loss: 0.4894 - val_accuracy: 0.7790 - lr: 0.0010
# Epoch 4/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.7807
# Epoch 4: val_loss improved from 0.48940 to 0.48534, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4843 - accuracy: 0.7807 - val_loss: 0.4853 - val_accuracy: 0.7798 - lr: 0.0010
# Epoch 5/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.7828
# Epoch 5: val_loss improved from 0.48534 to 0.48268, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4809 - accuracy: 0.7828 - val_loss: 0.4827 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 6/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4784 - accuracy: 0.7843
# Epoch 6: val_loss improved from 0.48268 to 0.48069, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4784 - accuracy: 0.7843 - val_loss: 0.4807 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 7/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4766 - accuracy: 0.7854
# Epoch 7: val_loss improved from 0.48069 to 0.47925, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4766 - accuracy: 0.7854 - val_loss: 0.4793 - val_accuracy: 0.7843 - lr: 0.0010
# Epoch 8/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4752 - accuracy: 0.7862
# Epoch 8: val_loss improved from 0.47925 to 0.47785, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4752 - accuracy: 0.7862 - val_loss: 0.4778 - val_accuracy: 0.7851 - lr: 0.0010
# Epoch 9/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.7868
# Epoch 9: val_loss improved from 0.47785 to 0.47692, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4740 - accuracy: 0.7868 - val_loss: 0.4769 - val_accuracy: 0.7857 - lr: 0.0010
# Epoch 10/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4730 - accuracy: 0.7872
# Epoch 10: val_loss improved from 0.47692 to 0.47624, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4730 - accuracy: 0.7872 - val_loss: 0.4762 - val_accuracy: 0.7859 - lr: 0.0010
# Epoch 11/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.7877
# Epoch 11: val_loss improved from 0.47624 to 0.47582, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 90s 1ms/step - loss: 0.4722 - accuracy: 0.7877 - val_loss: 0.4758 - val_accuracy: 0.7850 - lr: 0.0010
# Epoch 12/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.7881
# Epoch 12: val_loss improved from 0.47582 to 0.47532, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4716 - accuracy: 0.7881 - val_loss: 0.4753 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 13/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.7883
# Epoch 13: val_loss improved from 0.47532 to 0.47475, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4710 - accuracy: 0.7883 - val_loss: 0.4747 - val_accuracy: 0.7867 - lr: 0.0010
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.7886
# Epoch 14: val_loss did not improve from 0.47475
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4705 - accuracy: 0.7886 - val_loss: 0.4748 - val_accuracy: 0.7882 - lr: 0.0010
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7889
# Epoch 15: val_loss improved from 0.47475 to 0.47394, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4700 - accuracy: 0.7889 - val_loss: 0.4739 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.7890
# Epoch 16: val_loss improved from 0.47394 to 0.47362, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4697 - accuracy: 0.7890 - val_loss: 0.4736 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4693 - accuracy: 0.7892
# Epoch 17: val_loss improved from 0.47362 to 0.47323, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4693 - accuracy: 0.7892 - val_loss: 0.4732 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.7894
# Epoch 18: val_loss improved from 0.47323 to 0.47312, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4690 - accuracy: 0.7894 - val_loss: 0.4731 - val_accuracy: 0.7870 - lr: 0.0010
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.7894
# Epoch 19: val_loss improved from 0.47312 to 0.47296, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.4688 - accuracy: 0.7894 - val_loss: 0.4730 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.7896
# Epoch 20: val_loss did not improve from 0.47296
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4686 - accuracy: 0.7896 - val_loss: 0.4730 - val_accuracy: 0.7859 - lr: 0.0010
# Epoch 21/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.7898
# Epoch 21: val_loss improved from 0.47296 to 0.47264, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4684 - accuracy: 0.7898 - val_loss: 0.4726 - val_accuracy: 0.7879 - lr: 0.0010
# Epoch 22/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.7898
# Epoch 22: val_loss improved from 0.47264 to 0.47237, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 110s 1ms/step - loss: 0.4682 - accuracy: 0.7898 - val_loss: 0.4724 - val_accuracy: 0.7873 - lr: 0.0010
# Epoch 23/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4680 - accuracy: 0.7898
# Epoch 23: val_loss did not improve from 0.47237
# 88854/88854 [==============================] - 105s 1ms/step - loss: 0.4680 - accuracy: 0.7898 - val_loss: 0.4725 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 24/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.7899
# Epoch 24: val_loss did not improve from 0.47237
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4678 - accuracy: 0.7899 - val_loss: 0.4724 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 25/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.7900
# Epoch 25: val_loss improved from 0.47237 to 0.47228, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4677 - accuracy: 0.7900 - val_loss: 0.4723 - val_accuracy: 0.7867 - lr: 0.0010
# Epoch 26/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.7900
# Epoch 26: val_loss improved from 0.47228 to 0.47212, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4676 - accuracy: 0.7900 - val_loss: 0.4721 - val_accuracy: 0.7872 - lr: 0.0010
# Epoch 27/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7901
# Epoch 27: val_loss improved from 0.47212 to 0.47189, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4675 - accuracy: 0.7901 - val_loss: 0.4719 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 28/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.7902
# Epoch 28: val_loss improved from 0.47189 to 0.47181, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4673 - accuracy: 0.7902 - val_loss: 0.4718 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 29/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7903
# Epoch 29: val_loss did not improve from 0.47181
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4672 - accuracy: 0.7903 - val_loss: 0.4718 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 30/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7903
# Epoch 30: val_loss improved from 0.47181 to 0.47177, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4672 - accuracy: 0.7903 - val_loss: 0.4718 - val_accuracy: 0.7879 - lr: 0.0010
# Epoch 31/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.7903
# Epoch 31: val_loss improved from 0.47177 to 0.47166, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4671 - accuracy: 0.7903 - val_loss: 0.4717 - val_accuracy: 0.7880 - lr: 0.0010
# Epoch 32/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.7903
# Epoch 32: val_loss did not improve from 0.47166
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4670 - accuracy: 0.7903 - val_loss: 0.4719 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 33/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.7903
# Epoch 33: val_loss did not improve from 0.47166
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4669 - accuracy: 0.7903 - val_loss: 0.4717 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 34/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.7904
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 34: val_loss did not improve from 0.47166
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4669 - accuracy: 0.7904 - val_loss: 0.4717 - val_accuracy: 0.7872 - lr: 0.0010
# Epoch 35/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.7906
# Epoch 35: val_loss improved from 0.47166 to 0.47144, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4663 - accuracy: 0.7906 - val_loss: 0.4714 - val_accuracy: 0.7877 - lr: 1.0000e-04
# Epoch 36/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7907
# Epoch 36: val_loss improved from 0.47144 to 0.47141, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4662 - accuracy: 0.7907 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 37/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7908
# Epoch 37: val_loss improved from 0.47141 to 0.47139, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4662 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7876 - lr: 1.0000e-04
# Epoch 38/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7907
# Epoch 38: val_loss improved from 0.47139 to 0.47138, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4662 - accuracy: 0.7907 - val_loss: 0.4714 - val_accuracy: 0.7877 - lr: 1.0000e-04
# Epoch 39/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7908
# Epoch 39: val_loss did not improve from 0.47138
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4662 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 40/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7907
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 40: val_loss improved from 0.47138 to 0.47138, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4662 - accuracy: 0.7907 - val_loss: 0.4714 - val_accuracy: 0.7874 - lr: 1.0000e-04
# Epoch 41/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7907
# Epoch 41: val_loss improved from 0.47138 to 0.47136, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4661 - accuracy: 0.7907 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-05
# Epoch 42/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 42: val_loss improved from 0.47136 to 0.47136, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7878 - lr: 1.0000e-05
# Epoch 43/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 43: val_loss improved from 0.47136 to 0.47136, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-05
# Epoch 44/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 44: val_loss improved from 0.47136 to 0.47136, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-05
# Epoch 45/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 45: val_loss did not improve from 0.47136
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7878 - lr: 1.0000e-06
# Epoch 46/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 46: val_loss did not improve from 0.47136
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7879 - lr: 1.0000e-06
# Epoch 47/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 47: val_loss did not improve from 0.47136
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7878 - lr: 1.0000e-06
# Epoch 48/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7908
# Epoch 48: val_loss improved from 0.47136 to 0.47136, saving model to models\m_count_row_1.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4661 - accuracy: 0.7908 - val_loss: 0.4714 - val_accuracy: 0.7878 - lr: 1.0000e-06
# Epoch 48: early stopping
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 986us/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79       177
#            1       0.78      0.86      0.82       182
#
#     accuracy                           0.81       359
#    macro avg       0.81      0.81      0.81       359
# weighted avg       0.81      0.81      0.81       359
#
# Accuracy: 0.807799442896936
# ╔══════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                     ║
# ║                              -------------------                                     ║
# ║                              Metric: count                                           ║
# ║                              Preprocessing row: 2                                    ║
# ║                              Removing stop words: False                              ║
# ╚══════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_2.csv
# Load test data from data/csv_rows/test_row_2.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5303 - accuracy: 0.7505
# Epoch 1: val_loss improved from inf to 0.50337, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.5303 - accuracy: 0.7505 - val_loss: 0.5034 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 2/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7758
# Epoch 2: val_loss improved from 0.50337 to 0.48993, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 92s 1ms/step - loss: 0.4934 - accuracy: 0.7758 - val_loss: 0.4899 - val_accuracy: 0.7780 - lr: 0.0010
# Epoch 3/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.7813
# Epoch 3: val_loss improved from 0.48993 to 0.48390, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4840 - accuracy: 0.7813 - val_loss: 0.4839 - val_accuracy: 0.7816 - lr: 0.0010
# Epoch 4/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.7840
# Epoch 4: val_loss improved from 0.48390 to 0.48004, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4790 - accuracy: 0.7840 - val_loss: 0.4800 - val_accuracy: 0.7829 - lr: 0.0010
# Epoch 5/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.7860
# Epoch 5: val_loss improved from 0.48004 to 0.47751, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4757 - accuracy: 0.7860 - val_loss: 0.4775 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 6/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7874
# Epoch 6: val_loss improved from 0.47751 to 0.47560, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4733 - accuracy: 0.7874 - val_loss: 0.4756 - val_accuracy: 0.7856 - lr: 0.0010
# Epoch 7/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.7883
# Epoch 7: val_loss improved from 0.47560 to 0.47418, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4715 - accuracy: 0.7883 - val_loss: 0.4742 - val_accuracy: 0.7862 - lr: 0.0010
# Epoch 8/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4701 - accuracy: 0.7891
# Epoch 8: val_loss improved from 0.47418 to 0.47288, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4701 - accuracy: 0.7891 - val_loss: 0.4729 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 9/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.7896
# Epoch 9: val_loss improved from 0.47288 to 0.47195, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4690 - accuracy: 0.7896 - val_loss: 0.4720 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 10/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.7901
# Epoch 10: val_loss improved from 0.47195 to 0.47131, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4681 - accuracy: 0.7901 - val_loss: 0.4713 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 11/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.7906
# Epoch 11: val_loss improved from 0.47131 to 0.47097, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4673 - accuracy: 0.7906 - val_loss: 0.4710 - val_accuracy: 0.7869 - lr: 0.0010
# Epoch 12/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.7911
# Epoch 12: val_loss improved from 0.47097 to 0.47047, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4667 - accuracy: 0.7911 - val_loss: 0.4705 - val_accuracy: 0.7890 - lr: 0.0010
# Epoch 13/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7912
# Epoch 13: val_loss improved from 0.47047 to 0.46990, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4661 - accuracy: 0.7912 - val_loss: 0.4699 - val_accuracy: 0.7887 - lr: 0.0010
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.7916
# Epoch 14: val_loss did not improve from 0.46990
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4656 - accuracy: 0.7916 - val_loss: 0.4700 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7918
# Epoch 15: val_loss improved from 0.46990 to 0.46911, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 93s 1ms/step - loss: 0.4652 - accuracy: 0.7918 - val_loss: 0.4691 - val_accuracy: 0.7899 - lr: 0.0010
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.7921
# Epoch 16: val_loss improved from 0.46911 to 0.46882, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4648 - accuracy: 0.7921 - val_loss: 0.4688 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4645 - accuracy: 0.7923
# Epoch 17: val_loss improved from 0.46882 to 0.46841, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4645 - accuracy: 0.7923 - val_loss: 0.4684 - val_accuracy: 0.7893 - lr: 0.0010
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4642 - accuracy: 0.7923
# Epoch 18: val_loss improved from 0.46841 to 0.46830, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4642 - accuracy: 0.7923 - val_loss: 0.4683 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.7925
# Epoch 19: val_loss improved from 0.46830 to 0.46826, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4640 - accuracy: 0.7925 - val_loss: 0.4683 - val_accuracy: 0.7889 - lr: 0.0010
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7928
# Epoch 20: val_loss improved from 0.46826 to 0.46825, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 94s 1ms/step - loss: 0.4638 - accuracy: 0.7928 - val_loss: 0.4682 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 21/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.7928
# Epoch 21: val_loss improved from 0.46825 to 0.46788, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4636 - accuracy: 0.7928 - val_loss: 0.4679 - val_accuracy: 0.7906 - lr: 0.0010
# Epoch 22/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.7928
# Epoch 22: val_loss improved from 0.46788 to 0.46762, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4634 - accuracy: 0.7928 - val_loss: 0.4676 - val_accuracy: 0.7896 - lr: 0.0010
# Epoch 23/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.7929
# Epoch 23: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 95s 1ms/step - loss: 0.4632 - accuracy: 0.7929 - val_loss: 0.4677 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 24/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.7931
# Epoch 24: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4630 - accuracy: 0.7931 - val_loss: 0.4676 - val_accuracy: 0.7909 - lr: 0.0010
# Epoch 25/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4629 - accuracy: 0.7931
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 25: val_loss did not improve from 0.46762
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4629 - accuracy: 0.7931 - val_loss: 0.4677 - val_accuracy: 0.7885 - lr: 0.0010
# Epoch 26/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4623 - accuracy: 0.7936
# Epoch 26: val_loss improved from 0.46762 to 0.46716, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4623 - accuracy: 0.7936 - val_loss: 0.4672 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 27/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 27: val_loss did not improve from 0.46716
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4672 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 28/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7937
# Epoch 28: val_loss improved from 0.46716 to 0.46713, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4622 - accuracy: 0.7937 - val_loss: 0.4671 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 29/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 29: val_loss improved from 0.46713 to 0.46710, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 30/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 30: val_loss improved from 0.46710 to 0.46709, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 31/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 31: val_loss improved from 0.46709 to 0.46709, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7906 - lr: 1.0000e-04
# Epoch 32/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7937
# Epoch 32: val_loss improved from 0.46709 to 0.46707, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4622 - accuracy: 0.7937 - val_loss: 0.4671 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 33/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7936
# Epoch 33: val_loss improved from 0.46707 to 0.46707, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4622 - accuracy: 0.7936 - val_loss: 0.4671 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 34/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7936
# Epoch 34: val_loss improved from 0.46707 to 0.46704, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4621 - accuracy: 0.7936 - val_loss: 0.4670 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 35/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 35: val_loss did not improve from 0.46704
# 88854/88854 [==============================] - 96s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 36/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 36: val_loss improved from 0.46704 to 0.46704, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 97s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 37/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 37: val_loss improved from 0.46704 to 0.46702, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 38/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 38: val_loss improved from 0.46702 to 0.46702, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 39/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 39: val_loss improved from 0.46702 to 0.46701, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 100s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 40/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7937
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 40: val_loss did not improve from 0.46701
# 88854/88854 [==============================] - 98s 1ms/step - loss: 0.4621 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7896 - lr: 1.0000e-04
# Epoch 41/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7936
# Epoch 41: val_loss improved from 0.46701 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4620 - accuracy: 0.7936 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 42/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 42: val_loss improved from 0.46699 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 99s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 43/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 43: val_loss improved from 0.46699 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7905 - lr: 1.0000e-05
# Epoch 44/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7937
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 44: val_loss improved from 0.46699 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 101s 1ms/step - loss: 0.4620 - accuracy: 0.7937 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-05
# Epoch 45/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 45: val_loss improved from 0.46699 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 46/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 46: val_loss improved from 0.46699 to 0.46699, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 47/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 47: val_loss improved from 0.46699 to 0.46698, saving model to models\m_count_row_2.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 48/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4620 - accuracy: 0.7938
# Epoch 48: val_loss did not improve from 0.46698
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4670 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 48: early stopping
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 995us/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       177
#            1       0.78      0.85      0.81       182
#
#     accuracy                           0.80       359
#    macro avg       0.81      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.8022284122562674
# ╔═════════════════════════════════════════════════════════════════════════════════════╗
# ║                              Sentiment Analysis:                                    ║
# ║                              -------------------                                    ║
# ║                              Metric: count                                          ║
# ║                              Preprocessing row: 3                                   ║
# ║                              Removing stop words: True                              ║
# ╚═════════════════════════════════════════════════════════════════════════════════════╝
#
# Load train data from data/csv_rows/train_row_3.csv
# Load test data from data/csv_rows/test_row_3.csv
#
#
#
# ╔════════════════════════════════════════╗
# ║          Logistic Regression:          ║
# ╚════════════════════════════════════════╝
# Epoch 1/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.7201
# Epoch 1: val_loss improved from inf to 0.53031, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.5581 - accuracy: 0.7201 - val_loss: 0.5303 - val_accuracy: 0.7451 - lr: 0.0010
# Epoch 2/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.7505
# Epoch 2: val_loss improved from 0.53031 to 0.51649, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.5208 - accuracy: 0.7505 - val_loss: 0.5165 - val_accuracy: 0.7546 - lr: 0.0010
# Epoch 3/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5112 - accuracy: 0.7575
# Epoch 3: val_loss improved from 0.51649 to 0.51011, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 106s 1ms/step - loss: 0.5112 - accuracy: 0.7575 - val_loss: 0.5101 - val_accuracy: 0.7583 - lr: 0.0010
# Epoch 4/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5059 - accuracy: 0.7609
# Epoch 4: val_loss improved from 0.51011 to 0.50619, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 103s 1ms/step - loss: 0.5059 - accuracy: 0.7609 - val_loss: 0.5062 - val_accuracy: 0.7612 - lr: 0.0010
# Epoch 5/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.7631
# Epoch 5: val_loss improved from 0.50619 to 0.50359, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 104s 1ms/step - loss: 0.5025 - accuracy: 0.7631 - val_loss: 0.5036 - val_accuracy: 0.7622 - lr: 0.0010
# Epoch 6/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.7648
# Epoch 6: val_loss improved from 0.50359 to 0.50154, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.5001 - accuracy: 0.7648 - val_loss: 0.5015 - val_accuracy: 0.7632 - lr: 0.0010
# Epoch 7/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4982 - accuracy: 0.7660
# Epoch 7: val_loss improved from 0.50154 to 0.49993, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4982 - accuracy: 0.7660 - val_loss: 0.4999 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 8/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7665
# Epoch 8: val_loss improved from 0.49993 to 0.49877, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4968 - accuracy: 0.7665 - val_loss: 0.4988 - val_accuracy: 0.7654 - lr: 0.0010
# Epoch 9/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.7675
# Epoch 9: val_loss improved from 0.49877 to 0.49782, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4956 - accuracy: 0.7675 - val_loss: 0.4978 - val_accuracy: 0.7658 - lr: 0.0010
# Epoch 10/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7679
# Epoch 10: val_loss improved from 0.49782 to 0.49706, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 107s 1ms/step - loss: 0.4947 - accuracy: 0.7679 - val_loss: 0.4971 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 11/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.7684
# Epoch 11: val_loss improved from 0.49706 to 0.49673, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4939 - accuracy: 0.7684 - val_loss: 0.4967 - val_accuracy: 0.7658 - lr: 0.0010
# Epoch 12/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7688
# Epoch 12: val_loss improved from 0.49673 to 0.49593, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4932 - accuracy: 0.7688 - val_loss: 0.4959 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 13/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.7692
# Epoch 13: val_loss improved from 0.49593 to 0.49546, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4926 - accuracy: 0.7692 - val_loss: 0.4955 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4921 - accuracy: 0.7694
# Epoch 14: val_loss improved from 0.49546 to 0.49534, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 107s 1ms/step - loss: 0.4921 - accuracy: 0.7694 - val_loss: 0.4953 - val_accuracy: 0.7678 - lr: 0.0010
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.7696
# Epoch 15: val_loss improved from 0.49534 to 0.49467, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4917 - accuracy: 0.7696 - val_loss: 0.4947 - val_accuracy: 0.7678 - lr: 0.0010
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7699
# Epoch 16: val_loss improved from 0.49467 to 0.49440, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 109s 1ms/step - loss: 0.4913 - accuracy: 0.7699 - val_loss: 0.4944 - val_accuracy: 0.7677 - lr: 0.0010
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4910 - accuracy: 0.7700
# Epoch 17: val_loss improved from 0.49440 to 0.49404, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4910 - accuracy: 0.7700 - val_loss: 0.4940 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7702
# Epoch 18: val_loss improved from 0.49404 to 0.49386, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 108s 1ms/step - loss: 0.4907 - accuracy: 0.7702 - val_loss: 0.4939 - val_accuracy: 0.7675 - lr: 0.0010
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.7703
# Epoch 19: val_loss improved from 0.49386 to 0.49370, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 109s 1ms/step - loss: 0.4904 - accuracy: 0.7703 - val_loss: 0.4937 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4902 - accuracy: 0.7704
# Epoch 20: val_loss improved from 0.49370 to 0.49365, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 109s 1ms/step - loss: 0.4902 - accuracy: 0.7704 - val_loss: 0.4937 - val_accuracy: 0.7671 - lr: 0.0010
# Epoch 21/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.7704
# Epoch 21: val_loss improved from 0.49365 to 0.49337, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4900 - accuracy: 0.7704 - val_loss: 0.4934 - val_accuracy: 0.7688 - lr: 0.0010
# Epoch 22/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4898 - accuracy: 0.7706
# Epoch 22: val_loss improved from 0.49337 to 0.49316, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 111s 1ms/step - loss: 0.4898 - accuracy: 0.7706 - val_loss: 0.4932 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 23/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4896 - accuracy: 0.7707
# Epoch 23: val_loss improved from 0.49316 to 0.49303, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4896 - accuracy: 0.7707 - val_loss: 0.4930 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 24/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.7708
# Epoch 24: val_loss did not improve from 0.49303
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4895 - accuracy: 0.7708 - val_loss: 0.4931 - val_accuracy: 0.7691 - lr: 0.0010
# Epoch 25/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.7707
# Epoch 25: val_loss did not improve from 0.49303
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4893 - accuracy: 0.7707 - val_loss: 0.4931 - val_accuracy: 0.7673 - lr: 0.0010
# Epoch 26/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.7710
# Epoch 26: val_loss improved from 0.49303 to 0.49286, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4892 - accuracy: 0.7710 - val_loss: 0.4929 - val_accuracy: 0.7681 - lr: 0.0010
# Epoch 27/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.7709
# Epoch 27: val_loss improved from 0.49286 to 0.49270, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 113s 1ms/step - loss: 0.4891 - accuracy: 0.7709 - val_loss: 0.4927 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 28/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.7710
# Epoch 28: val_loss improved from 0.49270 to 0.49257, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 115s 1ms/step - loss: 0.4890 - accuracy: 0.7710 - val_loss: 0.4926 - val_accuracy: 0.7687 - lr: 0.0010
# Epoch 29/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4889 - accuracy: 0.7711
# Epoch 29: val_loss improved from 0.49257 to 0.49253, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4889 - accuracy: 0.7711 - val_loss: 0.4925 - val_accuracy: 0.7693 - lr: 0.0010
# Epoch 30/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.7712
# Epoch 30: val_loss improved from 0.49253 to 0.49245, saving model to models\m_count_row_3.hdf5
# 88854/88854 [==============================] - 112s 1ms/step - loss: 0.4888 - accuracy: 0.7712 - val_loss: 0.4925 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 31/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.7710
# ...
# 88854/88854 [==============================] - 162s 2ms/step - loss: 0.4979 - accuracy: 0.7639 - val_loss: 0.5003 - val_accuracy: 0.7620 - lr: 0.0010
# Epoch 14/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4974 - accuracy: 0.7642
# Epoch 14: val_loss improved from 0.50027 to 0.50009, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 160s 2ms/step - loss: 0.4974 - accuracy: 0.7642 - val_loss: 0.5001 - val_accuracy: 0.7626 - lr: 0.0010
# Epoch 15/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4970 - accuracy: 0.7645
# Epoch 15: val_loss improved from 0.50009 to 0.49947, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 164s 2ms/step - loss: 0.4970 - accuracy: 0.7645 - val_loss: 0.4995 - val_accuracy: 0.7630 - lr: 0.0010
# Epoch 16/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4966 - accuracy: 0.7648
# Epoch 16: val_loss improved from 0.49947 to 0.49918, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 162s 2ms/step - loss: 0.4966 - accuracy: 0.7648 - val_loss: 0.4992 - val_accuracy: 0.7629 - lr: 0.0010
# Epoch 17/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.7649
# Epoch 17: val_loss improved from 0.49918 to 0.49881, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 160s 2ms/step - loss: 0.4963 - accuracy: 0.7649 - val_loss: 0.4988 - val_accuracy: 0.7631 - lr: 0.0010
# Epoch 18/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4960 - accuracy: 0.7651
# Epoch 18: val_loss improved from 0.49881 to 0.49866, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 171s 2ms/step - loss: 0.4960 - accuracy: 0.7651 - val_loss: 0.4987 - val_accuracy: 0.7630 - lr: 0.0010
# Epoch 19/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4957 - accuracy: 0.7651
# Epoch 19: val_loss improved from 0.49866 to 0.49848, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 157s 2ms/step - loss: 0.4957 - accuracy: 0.7651 - val_loss: 0.4985 - val_accuracy: 0.7626 - lr: 0.0010
# Epoch 20/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.7652
# Epoch 20: val_loss improved from 0.49848 to 0.49833, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 158s 2ms/step - loss: 0.4955 - accuracy: 0.7652 - val_loss: 0.4983 - val_accuracy: 0.7628 - lr: 0.0010
# Epoch 21/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.7654
# Epoch 21: val_loss improved from 0.49833 to 0.49815, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 156s 2ms/step - loss: 0.4953 - accuracy: 0.7654 - val_loss: 0.4981 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 22/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4951 - accuracy: 0.7655
# Epoch 22: val_loss improved from 0.49815 to 0.49792, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 156s 2ms/step - loss: 0.4951 - accuracy: 0.7655 - val_loss: 0.4979 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 23/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7656
# Epoch 23: val_loss improved from 0.49792 to 0.49780, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 166s 2ms/step - loss: 0.4949 - accuracy: 0.7656 - val_loss: 0.4978 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 24/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7657
# Epoch 24: val_loss did not improve from 0.49780
# 88854/88854 [==============================] - 166s 2ms/step - loss: 0.4947 - accuracy: 0.7657 - val_loss: 0.4979 - val_accuracy: 0.7638 - lr: 0.0010
# Epoch 25/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4946 - accuracy: 0.7658
# Epoch 25: val_loss did not improve from 0.49780
# 88854/88854 [==============================] - 168s 2ms/step - loss: 0.4946 - accuracy: 0.7658 - val_loss: 0.4979 - val_accuracy: 0.7628 - lr: 0.0010
# Epoch 26/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4945 - accuracy: 0.7658
# Epoch 26: val_loss improved from 0.49780 to 0.49762, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 172s 2ms/step - loss: 0.4945 - accuracy: 0.7658 - val_loss: 0.4976 - val_accuracy: 0.7632 - lr: 0.0010
# Epoch 27/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.7658
# Epoch 27: val_loss improved from 0.49762 to 0.49748, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 170s 2ms/step - loss: 0.4943 - accuracy: 0.7658 - val_loss: 0.4975 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 28/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.7658
# Epoch 28: val_loss improved from 0.49748 to 0.49731, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 168s 2ms/step - loss: 0.4942 - accuracy: 0.7658 - val_loss: 0.4973 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 29/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.7661
# Epoch 29: val_loss improved from 0.49731 to 0.49728, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 171s 2ms/step - loss: 0.4941 - accuracy: 0.7661 - val_loss: 0.4973 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 30/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7662
# Epoch 30: val_loss improved from 0.49728 to 0.49720, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 171s 2ms/step - loss: 0.4940 - accuracy: 0.7662 - val_loss: 0.4972 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 31/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7660
# Epoch 31: val_loss improved from 0.49720 to 0.49712, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 175s 2ms/step - loss: 0.4940 - accuracy: 0.7660 - val_loss: 0.4971 - val_accuracy: 0.7641 - lr: 0.0010
# Epoch 32/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.7661
# Epoch 32: val_loss did not improve from 0.49712
# 88854/88854 [==============================] - 173s 2ms/step - loss: 0.4939 - accuracy: 0.7661 - val_loss: 0.4972 - val_accuracy: 0.7635 - lr: 0.0010
# Epoch 33/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7661
# Epoch 33: val_loss improved from 0.49712 to 0.49705, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 174s 2ms/step - loss: 0.4938 - accuracy: 0.7661 - val_loss: 0.4970 - val_accuracy: 0.7642 - lr: 0.0010
# Epoch 34/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7661
# Epoch 34: val_loss did not improve from 0.49705
# 88854/88854 [==============================] - 170s 2ms/step - loss: 0.4938 - accuracy: 0.7661 - val_loss: 0.4971 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 35/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4937 - accuracy: 0.7662
# Epoch 35: val_loss did not improve from 0.49705
# 88854/88854 [==============================] - 174s 2ms/step - loss: 0.4937 - accuracy: 0.7662 - val_loss: 0.4971 - val_accuracy: 0.7632 - lr: 0.0010
# Epoch 36/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7663
# Epoch 36: val_loss improved from 0.49705 to 0.49689, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 175s 2ms/step - loss: 0.4936 - accuracy: 0.7663 - val_loss: 0.4969 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 37/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7663
# Epoch 37: val_loss improved from 0.49689 to 0.49685, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 174s 2ms/step - loss: 0.4936 - accuracy: 0.7663 - val_loss: 0.4968 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 38/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.7663
# Epoch 38: val_loss improved from 0.49685 to 0.49683, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 179s 2ms/step - loss: 0.4935 - accuracy: 0.7663 - val_loss: 0.4968 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 39/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.7663
# Epoch 39: val_loss improved from 0.49683 to 0.49675, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4935 - accuracy: 0.7663 - val_loss: 0.4967 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 40/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7664
# Epoch 40: val_loss did not improve from 0.49675
# 88854/88854 [==============================] - 176s 2ms/step - loss: 0.4934 - accuracy: 0.7664 - val_loss: 0.4970 - val_accuracy: 0.7635 - lr: 0.0010
# Epoch 41/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7664
# Epoch 41: val_loss improved from 0.49675 to 0.49674, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4934 - accuracy: 0.7664 - val_loss: 0.4967 - val_accuracy: 0.7643 - lr: 0.0010
# Epoch 42/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7663
# Epoch 42: val_loss improved from 0.49674 to 0.49667, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4934 - accuracy: 0.7663 - val_loss: 0.4967 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 43/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.7664
# Epoch 43: val_loss did not improve from 0.49667
# 88854/88854 [==============================] - 177s 2ms/step - loss: 0.4933 - accuracy: 0.7664 - val_loss: 0.4968 - val_accuracy: 0.7635 - lr: 0.0010
# Epoch 44/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.7664
# Epoch 44: val_loss did not improve from 0.49667
# 88854/88854 [==============================] - 175s 2ms/step - loss: 0.4933 - accuracy: 0.7664 - val_loss: 0.4968 - val_accuracy: 0.7647 - lr: 0.0010
# Epoch 45/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.7664
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 45: val_loss did not improve from 0.49667
# 88854/88854 [==============================] - 179s 2ms/step - loss: 0.4933 - accuracy: 0.7664 - val_loss: 0.4967 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 46/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7667
# Epoch 46: val_loss improved from 0.49667 to 0.49665, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 182s 2ms/step - loss: 0.4929 - accuracy: 0.7667 - val_loss: 0.4967 - val_accuracy: 0.7644 - lr: 1.0000e-04
# Epoch 47/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7668
# Epoch 47: val_loss improved from 0.49665 to 0.49665, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4929 - accuracy: 0.7668 - val_loss: 0.4966 - val_accuracy: 0.7643 - lr: 1.0000e-04
# Epoch 48/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7667
# Epoch 48: val_loss improved from 0.49665 to 0.49664, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 184s 2ms/step - loss: 0.4929 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-04
# Epoch 49/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7668
# Epoch 49: val_loss improved from 0.49664 to 0.49663, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 180s 2ms/step - loss: 0.4929 - accuracy: 0.7668 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-04
# Epoch 50/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7667
# Epoch 50: val_loss improved from 0.49663 to 0.49662, saving model to models\m_count_row_5.hdf5
# 88854/88854 [==============================] - 184s 2ms/step - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-04
# Epoch 51/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7668
# Epoch 51: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4928 - accuracy: 0.7668 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-04
# Epoch 52/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7667
# Epoch 52: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 187s 2ms/step - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7643 - lr: 1.0000e-04
# Epoch 53/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7668
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 53: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4928 - accuracy: 0.7668 - val_loss: 0.4966 - val_accuracy: 0.7643 - lr: 1.0000e-04
# Epoch 54/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7667
# Epoch 54: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 186s 2ms/step - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-05
# Epoch 55/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7667
# Epoch 55: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 184s 2ms/step - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7644 - lr: 1.0000e-05
# Epoch 56/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7668
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 56: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 183s 2ms/step - loss: 0.4928 - accuracy: 0.7668 - val_loss: 0.4966 - val_accuracy: 0.7643 - lr: 1.0000e-05
# Epoch 57/100
# 88854/88854 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7667
# Epoch 57: val_loss did not improve from 0.49662
# 88854/88854 [==============================] - 181s 2ms/step - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.4966 - val_accuracy: 0.7643 - lr: 1.0000e-06
# Epoch 57: early stopping
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 5001
#
# =================================================================
# Total params: 5,001
# Trainable params: 5,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# 12/12 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       177
#            1       0.79      0.82      0.80       182
#
#     accuracy                           0.80       359
#    macro avg       0.80      0.80      0.80       359
# weighted avg       0.80      0.80      0.80       359
#
# Accuracy: 0.7966573816155988
